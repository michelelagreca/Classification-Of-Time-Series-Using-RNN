# %%
# %cd /content/drive/MyDrive/ANN2DL_HW2_Shared
# Out:
# /content/drive/MyDrive/ANN2DL_HW2_Shared

# %%
import tensorflow as tf
import numpy as np
import os
import random
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.rc('font', size=16) 
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import warnings
import logging

tfk = tf.keras
tfkl = tf.keras.layers
print(tf.__version__)
# Out:
# 2.9.2

# %%
# Random seed for reproducibility
seed = 42

random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)

# %%
x_file_path = "./original_data/x_train.npy"
y_file_path = "./original_data/y_train.npy"

X = np.load(x_file_path)
y = np.load(y_file_path)

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, random_state=seed)
X_train.shape, y_train.shape, X_val.shape, y_val.shape
# Out:
# ((1943, 36, 6), (1943,), (486, 36, 6), (486,))

# %%
y_train = tfk.utils.to_categorical(y_train)
y_val = tfk.utils.to_categorical(y_val)
y_train.shape, y_val.shape
# Out:
# ((1943, 12), (486, 12))

# %%
# Utility function to create folders and callbacks for training
from datetime import datetime

def create_folders_and_callbacks(model_name, experiments_name):

  exps_dir = os.path.join(experiments_name)
  if not os.path.exists(exps_dir):
      os.makedirs(exps_dir)

  now = datetime.now().strftime('%b%d_%H-%M-%S')

  exp_dir = os.path.join(exps_dir, model_name + '_' + str(now))
  if not os.path.exists(exp_dir):
      os.makedirs(exp_dir)
      
  callbacks = []

  # Model checkpoint
  # ----------------
  ckpt_dir = os.path.join(exp_dir, 'ckpts')
  if not os.path.exists(ckpt_dir):
      os.makedirs(ckpt_dir)

  ckpt_callback = tf.keras.callbacks.ModelCheckpoint(filepath=os.path.join(ckpt_dir, 'cp.ckpt'), 
                                                     save_weights_only=True, # True to save only weights
                                                     save_best_only=False) # True to save only the best epoch 
  callbacks.append(ckpt_callback)

  # Visualize Learning on Tensorboard
  # ---------------------------------
  tb_dir = os.path.join(exp_dir, 'tb_logs')
  if not os.path.exists(tb_dir):
      os.makedirs(tb_dir)
      
  # By default shows losses and metrics for both training and validation
  tb_callback = tf.keras.callbacks.TensorBoard(log_dir=tb_dir, 
                                               profile_batch=0,
                                               histogram_freq=1)  # if > 0 (epochs) shows weights histograms
  callbacks.append(tb_callback)

  return callbacks

# %%
from tensorflow.keras import backend

class MinimalRNNCell(tfkl.Layer):

    def __init__(self, units, **kwargs):
        self.units = units
        self.state_size = units
        super(MinimalRNNCell, self).__init__(**kwargs)

    def build(self, input_shape):
        self.kernel = self.add_weight(shape=(input_shape[-1], self.units),
                                      initializer='uniform',
                                      name='kernel')
        self.recurrent_kernel = self.add_weight(
            shape=(self.units, self.units),
            initializer='uniform',
            name='recurrent_kernel')
        self.built = True

    def call(self, inputs, states):
        prev_output = states[0]
        h = backend.dot(inputs, self.kernel)
        output = h + backend.dot(prev_output, self.recurrent_kernel)
        return output, [output]

# %%
from tensorflow.python import rnn_cell

cell = MinimalRNNCell(128)

# %%
from tensorflow.python import rnn_cell

def build_RNN_classifier(input_shape, classes, model_name, lr=0.001):
    # Build the neural network layer by layer
    input_layer = tfkl.Input(shape=input_shape, name='Input')

    rnn = tfkl.SimpleRNN(256)(input_layer)
    dropout1 = tfkl.Dropout(0.3, seed=seed)(rnn)

    classifier = tfkl.Dense(256, activation='relu')(dropout1)
    dropout2 = tfkl.Dropout(0.3, seed=seed)(classifier)

    output_layer = tfkl.Dense(classes, activation='softmax')(dropout2)

    # Connect input and output through the Model class
    model = tfk.Model(inputs=input_layer, outputs=output_layer, name=model_name)

    # Compile the model
    model.compile(loss=tfk.losses.CategoricalCrossentropy(), optimizer=tfk.optimizers.Adam(), metrics='accuracy')

    # Return the model
    return model

# %%
model_name = "RNN"
experiments_name = "No_oversampling_no_normalization"

input_shape = X_train.shape[1:]
classes = y_train.shape[-1]
batch_size = 128
epochs = 200

patience1 = 25
patience_plateau = 5
min_lr = 1e-5
lr_factor = 0.5

# %%
model = build_RNN_classifier(input_shape, classes, model_name)
model.summary()
# Out:
# Model: "RNN"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 36, 6)]           0
#
#  simple_rnn_3 (SimpleRNN)    (None, 256)               67328
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_6 (Dense)             (None, 256)               65792
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_7 (Dense)             (None, 12)                3084
#
# =================================================================
# Total params: 136,204
# Trainable params: 136,204
# Non-trainable params: 0
# _________________________________________________________________

# %%
# %cd ./andrea/RNN
# Out:
# /content/drive/MyDrive/ANN2DL_HW2_Shared/andrea/RNN

# %%
# Create folders and callbacks and fit
cbs = create_folders_and_callbacks(model_name, experiments_name)
cbs.append([tfk.callbacks.EarlyStopping(monitor='val_accuracy', mode='max', patience=patience1, restore_best_weights=True),
        tfk.callbacks.ReduceLROnPlateau(monitor='val_accuracy', mode='max', patience=patience_plateau, factor=lr_factor, min_lr=min_lr)])


# Train the model
history = model.fit(
    x = X_train,
    y = y_train,
    batch_size = batch_size,
    epochs = epochs,
    validation_data=(X_val, y_val),
    callbacks = cbs
).history
# Out:
# Epoch 1/200
# 16/16 [==============================] - 2s 53ms/step - loss: 2.3633 - accuracy: 0.2604 - val_loss: 1.9772 - val_accuracy: 0.3395 - lr: 0.0010
# Epoch 2/200
# 16/16 [==============================] - 1s 37ms/step - loss: 2.0271 - accuracy: 0.3464 - val_loss: 1.9072 - val_accuracy: 0.3621 - lr: 0.0010
# Epoch 3/200
# 16/16 [==============================] - 1s 34ms/step - loss: 1.8790 - accuracy: 0.3850 - val_loss: 1.8398 - val_accuracy: 0.3909 - lr: 0.0010
# Epoch 4/200
# 16/16 [==============================] - 1s 37ms/step - loss: 1.8023 - accuracy: 0.3891 - val_loss: 1.8173 - val_accuracy: 0.3930 - lr: 0.0010
# Epoch 5/200
# 16/16 [==============================] - 1s 35ms/step - loss: 1.7431 - accuracy: 0.4122 - val_loss: 1.7927 - val_accuracy: 0.3930 - lr: 0.0010
# Epoch 6/200
# 16/16 [==============================] - 1s 39ms/step - loss: 1.6752 - accuracy: 0.4354 - val_loss: 1.8182 - val_accuracy: 0.3663 - lr: 0.0010
# Epoch 7/200
# 16/16 [==============================] - 1s 34ms/step - loss: 1.6257 - accuracy: 0.4431 - val_loss: 1.7841 - val_accuracy: 0.4053 - lr: 0.0010
# Epoch 8/200
# 16/16 [==============================] - 1s 38ms/step - loss: 1.6233 - accuracy: 0.4375 - val_loss: 1.7699 - val_accuracy: 0.3930 - lr: 0.0010
# Epoch 9/200
# 16/16 [==============================] - 1s 35ms/step - loss: 1.5383 - accuracy: 0.4668 - val_loss: 1.7942 - val_accuracy: 0.3930 - lr: 0.0010
# Epoch 10/200
# 16/16 [==============================] - 1s 35ms/step - loss: 1.4822 - accuracy: 0.4858 - val_loss: 1.8009 - val_accuracy: 0.4033 - lr: 0.0010
# Epoch 11/200
# 16/16 [==============================] - 1s 35ms/step - loss: 1.4586 - accuracy: 0.4900 - val_loss: 1.7877 - val_accuracy: 0.3951 - lr: 0.0010
# Epoch 12/200
# 16/16 [==============================] - 1s 37ms/step - loss: 1.4347 - accuracy: 0.5003 - val_loss: 1.7750 - val_accuracy: 0.4156 - lr: 0.0010
# Epoch 13/200
# 16/16 [==============================] - 1s 36ms/step - loss: 1.3547 - accuracy: 0.5353 - val_loss: 1.7855 - val_accuracy: 0.4136 - lr: 0.0010
# Epoch 14/200
# 16/16 [==============================] - 1s 35ms/step - loss: 1.3441 - accuracy: 0.5332 - val_loss: 1.8027 - val_accuracy: 0.3889 - lr: 0.0010
# Epoch 15/200
# 16/16 [==============================] - 1s 39ms/step - loss: 1.2726 - accuracy: 0.5517 - val_loss: 1.8280 - val_accuracy: 0.4074 - lr: 0.0010
# Epoch 16/200
# 16/16 [==============================] - 1s 39ms/step - loss: 1.2708 - accuracy: 0.5656 - val_loss: 1.8027 - val_accuracy: 0.4095 - lr: 0.0010
# Epoch 17/200
# 16/16 [==============================] - 1s 34ms/step - loss: 1.2301 - accuracy: 0.5821 - val_loss: 1.8317 - val_accuracy: 0.4115 - lr: 0.0010
# Epoch 18/200
# 16/16 [==============================] - 1s 37ms/step - loss: 1.1636 - accuracy: 0.6006 - val_loss: 1.8054 - val_accuracy: 0.3992 - lr: 5.0000e-04
# Epoch 19/200
# 16/16 [==============================] - 1s 37ms/step - loss: 1.1376 - accuracy: 0.6083 - val_loss: 1.8055 - val_accuracy: 0.4239 - lr: 5.0000e-04
# Epoch 20/200
# 16/16 [==============================] - 1s 37ms/step - loss: 1.1284 - accuracy: 0.6022 - val_loss: 1.8163 - val_accuracy: 0.4156 - lr: 5.0000e-04
# Epoch 21/200
# 16/16 [==============================] - 1s 39ms/step - loss: 1.0780 - accuracy: 0.6392 - val_loss: 1.8139 - val_accuracy: 0.4280 - lr: 5.0000e-04
# Epoch 22/200
# 16/16 [==============================] - 1s 34ms/step - loss: 1.0539 - accuracy: 0.6305 - val_loss: 1.8500 - val_accuracy: 0.4342 - lr: 5.0000e-04
# Epoch 23/200
# 16/16 [==============================] - 1s 34ms/step - loss: 1.0399 - accuracy: 0.6320 - val_loss: 1.8040 - val_accuracy: 0.4095 - lr: 5.0000e-04
# Epoch 24/200
# 16/16 [==============================] - 1s 39ms/step - loss: 1.0481 - accuracy: 0.6469 - val_loss: 1.8510 - val_accuracy: 0.4198 - lr: 5.0000e-04
# Epoch 25/200
# 16/16 [==============================] - 1s 36ms/step - loss: 1.0213 - accuracy: 0.6372 - val_loss: 1.8442 - val_accuracy: 0.4280 - lr: 5.0000e-04
# Epoch 26/200
# 16/16 [==============================] - 1s 33ms/step - loss: 0.9796 - accuracy: 0.6701 - val_loss: 1.8438 - val_accuracy: 0.4156 - lr: 5.0000e-04
# Epoch 27/200
# 16/16 [==============================] - 1s 36ms/step - loss: 0.9770 - accuracy: 0.6799 - val_loss: 1.8863 - val_accuracy: 0.4177 - lr: 5.0000e-04
# Epoch 28/200
# 16/16 [==============================] - 1s 34ms/step - loss: 0.9113 - accuracy: 0.6933 - val_loss: 1.8695 - val_accuracy: 0.4177 - lr: 2.5000e-04
# Epoch 29/200
# 16/16 [==============================] - 1s 35ms/step - loss: 0.9207 - accuracy: 0.6958 - val_loss: 1.8708 - val_accuracy: 0.4177 - lr: 2.5000e-04
# Epoch 30/200
# 16/16 [==============================] - 1s 36ms/step - loss: 0.9033 - accuracy: 0.6897 - val_loss: 1.8600 - val_accuracy: 0.4053 - lr: 2.5000e-04
# Epoch 31/200
# 16/16 [==============================] - 1s 34ms/step - loss: 0.8947 - accuracy: 0.7061 - val_loss: 1.8666 - val_accuracy: 0.4156 - lr: 2.5000e-04
# Epoch 32/200
# 16/16 [==============================] - 1s 37ms/step - loss: 0.9102 - accuracy: 0.7025 - val_loss: 1.8509 - val_accuracy: 0.4218 - lr: 2.5000e-04
# Epoch 33/200
# 16/16 [==============================] - 1s 35ms/step - loss: 0.8762 - accuracy: 0.7128 - val_loss: 1.8632 - val_accuracy: 0.4239 - lr: 1.2500e-04
# Epoch 34/200
# 16/16 [==============================] - 1s 36ms/step - loss: 0.8597 - accuracy: 0.7005 - val_loss: 1.8774 - val_accuracy: 0.4136 - lr: 1.2500e-04
# Epoch 35/200
# 16/16 [==============================] - 1s 37ms/step - loss: 0.8500 - accuracy: 0.7077 - val_loss: 1.8699 - val_accuracy: 0.4177 - lr: 1.2500e-04
# Epoch 36/200
# 16/16 [==============================] - 1s 37ms/step - loss: 0.8610 - accuracy: 0.7010 - val_loss: 1.8694 - val_accuracy: 0.4218 - lr: 1.2500e-04
# Epoch 37/200
# 16/16 [==============================] - 1s 34ms/step - loss: 0.8333 - accuracy: 0.7149 - val_loss: 1.9007 - val_accuracy: 0.4198 - lr: 1.2500e-04
# Epoch 38/200
# 16/16 [==============================] - 1s 36ms/step - loss: 0.8270 - accuracy: 0.7174 - val_loss: 1.8654 - val_accuracy: 0.4239 - lr: 6.2500e-05
# Epoch 39/200
# 16/16 [==============================] - 1s 35ms/step - loss: 0.8418 - accuracy: 0.7216 - val_loss: 1.8744 - val_accuracy: 0.4280 - lr: 6.2500e-05
# Epoch 40/200
# 16/16 [==============================] - 1s 35ms/step - loss: 0.8412 - accuracy: 0.7365 - val_loss: 1.8725 - val_accuracy: 0.4177 - lr: 6.2500e-05
# Epoch 41/200
# 16/16 [==============================] - 1s 36ms/step - loss: 0.8353 - accuracy: 0.7164 - val_loss: 1.8779 - val_accuracy: 0.4156 - lr: 6.2500e-05
# Epoch 42/200
# 16/16 [==============================] - 1s 33ms/step - loss: 0.8147 - accuracy: 0.7252 - val_loss: 1.8875 - val_accuracy: 0.4156 - lr: 6.2500e-05
# Epoch 43/200
# 16/16 [==============================] - 1s 37ms/step - loss: 0.8277 - accuracy: 0.7210 - val_loss: 1.8820 - val_accuracy: 0.4177 - lr: 3.1250e-05
# Epoch 44/200
# 16/16 [==============================] - 1s 36ms/step - loss: 0.8550 - accuracy: 0.7051 - val_loss: 1.8836 - val_accuracy: 0.4239 - lr: 3.1250e-05
# Epoch 45/200
# 16/16 [==============================] - 1s 35ms/step - loss: 0.8098 - accuracy: 0.7226 - val_loss: 1.8845 - val_accuracy: 0.4198 - lr: 3.1250e-05
# Epoch 46/200
# 16/16 [==============================] - 1s 34ms/step - loss: 0.7940 - accuracy: 0.7355 - val_loss: 1.8847 - val_accuracy: 0.4198 - lr: 3.1250e-05
# Epoch 47/200
# 16/16 [==============================] - 1s 37ms/step - loss: 0.8100 - accuracy: 0.7277 - val_loss: 1.8845 - val_accuracy: 0.4177 - lr: 3.1250e-05

# %%
best_epoch = np.argmax(history['val_accuracy'])
plt.figure(figsize=(17,4))
plt.plot(history['loss'], label='Training loss', alpha=.8, color='#ff7f0e')
plt.plot(history['val_loss'], label='Validation loss', alpha=.9, color='#5a9aa5')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
plt.title('Categorical Crossentropy')
plt.legend()
plt.grid(alpha=.3)
plt.show()

plt.figure(figsize=(17,4))
plt.plot(history['accuracy'], label='Training accuracy', alpha=.8, color='#ff7f0e')
plt.plot(history['val_accuracy'], label='Validation accuracy', alpha=.9, color='#5a9aa5')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
plt.title('Accuracy')
plt.legend()
plt.grid(alpha=.3)
plt.show()

plt.figure(figsize=(17,4))
plt.plot(history['lr'], label='Learning Rate', alpha=.8, color='#ff7f0e')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
plt.legend()
plt.grid(alpha=.3)
plt.show()

# %%
# Predict the test set with the RNN
predictions = model.predict(X_val)
predictions.shape
# Out:
# 16/16 [==============================] - 0s 5ms/step
# (486, 12)

# %%
# Compute the confusion matrix
cm = confusion_matrix(np.argmax(y_val, axis=-1), np.argmax(predictions, axis=-1))

# Compute the classification metrics
accuracy = accuracy_score(np.argmax(y_val, axis=-1), np.argmax(predictions, axis=-1))
precision = precision_score(np.argmax(y_val, axis=-1), np.argmax(predictions, axis=-1), average='macro')
recall = recall_score(np.argmax(y_val, axis=-1), np.argmax(predictions, axis=-1), average='macro')
f1 = f1_score(np.argmax(y_val, axis=-1), np.argmax(predictions, axis=-1), average='macro')
print('Accuracy:',accuracy.round(4))
print('Precision:',precision.round(4))
print('Recall:',recall.round(4))
print('F1:',f1.round(4))

# Plot the confusion matrix
plt.figure(figsize=(10,8))
sns.heatmap(cm.T, cmap='Blues', xticklabels=range(classes), yticklabels=range(classes))
plt.xlabel('True labels')
plt.ylabel('Predicted labels')
plt.show()
# Out:
# Accuracy: 0.4342
# Precision: 0.3168
# Recall: 0.2854
# F1: 0.2868
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
#model.save(model_name)
# model = tfk.models.load_model(model_name)
