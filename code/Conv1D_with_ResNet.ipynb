# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/ANN2DL_HW2_Shared
# Out:
# /content/drive/MyDrive/ANN2DL_HW2_Shared

# %%
import tensorflow as tf
import numpy as np
import os
import random
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.rc('font', size=16) 
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.utils import resample
from sklearn.utils.class_weight import compute_class_weight
from imblearn.over_sampling import RandomOverSampler, SMOTE, ADASYN
from imblearn.combine import SMOTEENN, SMOTETomek
import shutil
import warnings
import logging

tfk = tf.keras
tfkl = tf.keras.layers
print(tf.__version__)
# Out:
# 2.9.2

# %%
# Random seed for reproducibility
seed = 42

random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)

# %%
normalization = 'standard'
axis = 2
class_weighting = False
oversampling = False

# %% [markdown]
# # Load and preprocess data

# %%
x_file_path = "./original_data/x_train.npy"
y_file_path = "./original_data/y_train.npy"

X = np.load(x_file_path)
y = np.load(y_file_path)

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.1, random_state=seed)
n_dimensions = X_train.shape[2]
X_train.shape, y_train.shape, X_val.shape, y_val.shape
# Out:
# ((2186, 36, 6), (2186,), (243, 36, 6), (243,))

# %%
label_mapping = {
    "Wish",
    "Another",
    "Comfortably",
    "Money",
    "Breathe",
    "Time",
    "Brain",
    "Echoes",
    "Wearing",
    "Sorrow",
    "Hey",
    "Shine"
}

# %% [markdown]
# ## Normalization

# %%
def normalize(X_train, axis, norm_type='no_norm'):
  axs = [0,1,2]
  axs.remove(axis)
  axs=tuple(axs)

  means = np.mean(X_train, axis=axs)
  stds = np.std(X_train, axis=axs)
  mins = np.min(X_train, axis=axs)
  maxs = np.max(X_train, axis=axs)

  params = {
      "means": means,
      "stds": stds,
      "mins": mins,
      "maxs": maxs
  }
  
  if norm_type=='standard':
    X_std_train = []
    
    for i in range(X_train.shape[axis]):
      data = np.take(X_train, i, axis=axis)
      data = (data - means[i]) / stds[i]
      X_std_train.append(data)

    X_std_train = tuple(X_std_train)
    X_std_train = np.stack(X_std_train, axis=axis)

    return X_std_train, params


  elif norm_type=='minmax':
    X_norm_train = []
    
    for i in range(X_train.shape[axis]):
      data = np.take(X_train, i, axis=axis)
      data = (data - mins[i]) / (maxs[i] - mins[i])
      X_norm_train.append(data)

    X_norm_train = tuple(X_norm_train)
    X_norm_train = np.stack(X_norm_train, axis=axis)

    return X_norm_train, params

  else:
    return X_train, params

# %%
def normalize_test(X, params, axis, norm_type='no_norm'):
  
  if norm_type=='standard':
    X_std_val = []

    means = params["means"]
    stds = params["stds"]
    mins = params["mins"]
    maxs = params["maxs"]

    for i in range(X.shape[axis]):
      data = np.take(X, i, axis=axis)
      data = (data - means[i]) / stds[i]
      X_std_val.append(data)

    X_std_val = tuple(X_std_val)
    X_std_val = np.stack(X_std_val, axis=axis)

    return X_std_val

  elif norm_type=='minmax':
    X_norm_val = []
    
    for i in range(X.shape[axis]):
      data = np.take(X, i, axis=axis)
      data = (data - mins[i]) / (maxs[i] - min)
      X_norm_val.append(data)

    X_norm_val = tuple(X_norm_val)
    X_norm_val = np.stack(X_norm_val, axis=axis)

    return X_norm_val

  else:
    return X

# %%
X_train_no_norm = X_train
X_train, p = normalize(X_train, axis, norm_type=normalization)
X_val = normalize_test(X_val, p, axis, norm_type=normalization)

# %% [markdown]
# ## Comput class weights

# %%
if class_weighting:
  class_weights = compute_class_weight(class_weight='balanced', classes=np.unique(y), y=y)

  fig = plt.figure(figsize=(21, 5))
  plt.bar(np.arange(12), class_weights, width=1, edgecolor="white", tick_label=list(label_mapping))
  plt.show()

# %%
if class_weighting:
  class_weights = dict(zip(np.arange(12), class_weights))
  class_weights

# %% [markdown]
# ## Random oversampling and undersampling

# %%
if oversampling:
  ros = RandomOverSampler(random_state=seed)
  smote = SMOTE(random_state=seed)
  adasyn = ADASYN(random_state=seed)
  smoteenn = SMOTEENN(random_state=seed)
  smote_tomek = SMOTETomek(random_state=seed)

  if noise:
    X_train = X_train_no_norm

  X1 = []

  for dim in range(n_dimensions):
    X_dim = X_train[:,:,dim]
    X1.append(X_dim)

  X1 = np.concatenate(X1, axis=1)
  X_ros, y_ros = adasyn.fit_resample(X1, y_train)
  X_ros = np.reshape(X_ros, (X_ros.shape[0], 36, 6), order='F')
  X_train, y_train = X_ros, y_ros

# %%
if oversampling:
  plt.bar(np.arange(12), np.argmax(y_ros), width=1, edgecolor="white", tick_label=list(np.arange(12)))
  plt.show()

# %% [markdown]
# # To categorical data

# %%
y_train = tfk.utils.to_categorical(y_train)
y_val = tfk.utils.to_categorical(y_val)
y_train.shape, y_val.shape
# Out:
# ((8282, 12), (243, 12))

# %%
X_train.shape, y_train.shape
# Out:
# ((8282, 36, 6), (8282, 12))

# %% [markdown]
# # Utility function and classes definitions

# %%
# Utility function to create folders and callbacks for training
from datetime import datetime

def create_folders_and_callbacks(model_name, experiments_name):

  exps_dir = os.path.join(experiments_name)
  if not os.path.exists(exps_dir):
      os.makedirs(exps_dir)

  now = datetime.now().strftime('%b%d_%H-%M-%S')

  exp_dir = os.path.join(exps_dir, model_name + '_' + str(now))
  if not os.path.exists(exp_dir):
      os.makedirs(exp_dir)
      
  callbacks = []

  # Model checkpoint
  # ----------------
  ckpt_dir = os.path.join(exp_dir, 'ckpts')
  if not os.path.exists(ckpt_dir):
      os.makedirs(ckpt_dir)

  ckpt_callback = tf.keras.callbacks.ModelCheckpoint(filepath=os.path.join(ckpt_dir, 'cp.ckpt'), 
                                                     save_weights_only=True, # True to save only weights
                                                     save_best_only=False) # True to save only the best epoch 
  callbacks.append(ckpt_callback)

  # Visualize Learning on Tensorboard
  # ---------------------------------
  tb_dir = os.path.join(exp_dir, 'tb_logs')
  if not os.path.exists(tb_dir):
      os.makedirs(tb_dir)
      
  # By default shows losses and metrics for both training and validation
  tb_callback = tf.keras.callbacks.TensorBoard(log_dir=tb_dir, 
                                               profile_batch=0,
                                               histogram_freq=1)  # if > 0 (epochs) shows weights histograms
  callbacks.append(tb_callback)

  return callbacks

# %% [markdown]
# # Model building function

# %%
def build_classifier(input_shape, classes, model_name, lr=0.001):
    # Build the neural network layer by layer
    input_layer = tfkl.Input(shape=input_shape, name='Input')

    # Feature extractor
    cnn1 = tfkl.Conv1D(128,3,padding='same',activation='relu')(input_layer)
    cnn2 = tfkl.Conv1D(128,3,padding='same',activation='relu')(cnn1)
    cnn = tfkl.Add()([cnn1, cnn2])
    cnn = tfkl.MaxPooling1D()(cnn)
    
    cnn1 = tfkl.Conv1D(256,3,padding='same',activation='relu')(cnn)
    cnn2 = tfkl.Conv1D(256,3,padding='same',activation='relu')(cnn1)
    cnn = tfkl.Add()([cnn1, cnn2])
    cnn = tfkl.MaxPooling1D()(cnn)

    cnn1 = tfkl.Conv1D(256,3,padding='same',activation='relu')(cnn)
    cnn2 = tfkl.Conv1D(256,3,padding='same',activation='relu')(cnn1)
    cnn = tfkl.Add()([cnn1, cnn2])
    cnn = tfkl.MaxPooling1D()(cnn)

    gap = tfkl.GlobalAveragePooling1D()(cnn)
    #gap = tfkl.Dropout(0.4, seed=seed)(gap)

    # Classifier
    classifier = tfkl.Dense(256, activation='relu')(gap)
    #classifier = tfkl.Dropout(0.4, seed=seed)(classifier)
    
    output_layer = tfkl.Dense(12, activation='softmax')(classifier)

    # Connect input and output through the Model class
    model = tfk.Model(inputs=input_layer, outputs=output_layer, name=model_name)

    # Compile the model
    model.compile(loss=tfk.losses.CategoricalCrossentropy(), optimizer=tfk.optimizers.Adam(lr), metrics='accuracy')

    # Return the model
    return model

# %% [markdown]
# # Parameters for training

# %%
model_name = "Conv1D_withAWGN_Oversampling_Standard"
experiments_name = "Conv1D_with_AWGN"

n_splits = 20

input_shape = X_train.shape[1:]
classes = y_train.shape[-1]
batch_size = 128
epochs = 200

patience1 = 20
patience_plateau = 5
min_lr = 1e-5
lr_factor = 0.5

# %% [markdown]
# # Build the model

# %%
model = build_classifier(input_shape, classes, model_name)
model.summary()
# Out:
# Model: "Conv1D_withAWGN_Oversampling_Standard"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  Input (InputLayer)             [(None, 36, 6)]      0           []
#
#  conv1d (Conv1D)                (None, 36, 128)      2432        ['Input[0][0]']
#
#  conv1d_1 (Conv1D)              (None, 36, 128)      49280       ['conv1d[0][0]']
#
#  add (Add)                      (None, 36, 128)      0           ['conv1d[0][0]',
#                                                                   'conv1d_1[0][0]']
#
#  max_pooling1d (MaxPooling1D)   (None, 18, 128)      0           ['add[0][0]']
#
#  conv1d_2 (Conv1D)              (None, 18, 256)      98560       ['max_pooling1d[0][0]']
#
#  conv1d_3 (Conv1D)              (None, 18, 256)      196864      ['conv1d_2[0][0]']
#
#  add_1 (Add)                    (None, 18, 256)      0           ['conv1d_2[0][0]',
#                                                                   'conv1d_3[0][0]']
#
#  max_pooling1d_1 (MaxPooling1D)  (None, 9, 256)      0           ['add_1[0][0]']
#
#  conv1d_4 (Conv1D)              (None, 9, 256)       196864      ['max_pooling1d_1[0][0]']
#
#  conv1d_5 (Conv1D)              (None, 9, 256)       196864      ['conv1d_4[0][0]']
#
#  add_2 (Add)                    (None, 9, 256)       0           ['conv1d_4[0][0]',
#                                                                   'conv1d_5[0][0]']
#
#  max_pooling1d_2 (MaxPooling1D)  (None, 4, 256)      0           ['add_2[0][0]']
#
#  global_average_pooling1d (Glob  (None, 256)         0           ['max_pooling1d_2[0][0]']
#  alAveragePooling1D)
#
#  dense (Dense)                  (None, 256)          65792       ['global_average_pooling1d[0][0]'
#                                                                  ]
#
#  dense_1 (Dense)                (None, 12)           3084        ['dense[0][0]']
#
# ==================================================================================================
# Total params: 809,740
# Trainable params: 809,740
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# # Bagging class definition

# %%
class BaggingModel(tfk.Model):
  def __init__(self, n_splits, inp, classes, model_name):
    super().__init__()
    self.n_splits = n_splits
    self.inp = inp
    self.classes = classes
    self.model_name = model_name
    self.models = []
    for i in range(self.n_splits):
      name = model_name + str(i)
      self.models.append(build_classifier(self.inp, self.classes, name))

  def fit(self,
    x=None,
    y=None,
    batch_size=None,
    epochs=1,
    verbose='auto',
    callbacks=None,
    validation_split=0.0,
    validation_data=None,
    shuffle=True,
    class_weight=None,
    sample_weight=None,
    initial_epoch=0,
    steps_per_epoch=None,
    validation_steps=None,
    validation_batch_size=None,
    validation_freq=1,
    max_queue_size=10,
    workers=1,
    use_multiprocessing=False):

    cbs = [tfk.callbacks.EarlyStopping(monitor='val_accuracy', mode='max', patience=patience1, restore_best_weights=False),
        tfk.callbacks.ReduceLROnPlateau(monitor='val_accuracy', mode='max', patience=patience_plateau, factor=lr_factor, min_lr=min_lr)]

    for i, model in enumerate(self.models):  
      # multiple train-test splits
      scores = []
      n_samples = x.shape[0]

      # select indexes
      ix = [i for i in range(n_samples)]
      train_ix = resample(ix, replace=True, n_samples=n_samples)
      test_ix = [x for x in ix if x not in train_ix]

      # select data
      X_train, y_train = tf.gather(x, indices=train_ix), y[train_ix]
      X_test, y_test = tf.gather(x, indices=test_ix), y[test_ix]

      # train model
      print("Training of model ", str(i))
      history = model.fit(
        x = X_train,
        y = y_train,
        batch_size = batch_size,
        epochs = epochs,
        validation_data=(X_test, y_test),
        callbacks = cbs,
        shuffle = True
      ).history
      print()

      score = model.evaluate(X_test, y_test)
      scores.append(score)
    
    print("Validation scores for each model:")

    for i, score in enumerate(scores):
      print("Score of model ", str(i))
      print(score)
      print()
        


  def predict(self, x):
    # make predictions
    yhats = [model.predict(x) for model in self.models]
    
    yhats = np.array(yhats)
   
    # sum across ensemble members
    summed = np.sum(yhats, axis=0)

    # argmax across classes
    result = np.argmax(summed, axis=1)

    result = tfk.utils.to_categorical(result)
    
    # return the result
    return result
    pass

  def save(self,
      filepath,
      overwrite=True,
      include_optimizer=True,
      save_format=None,
      signatures=None,
      options=None,
      save_traces=True
  ):

    parent_dir = filepath
    if os.path.exists(parent_dir):
            shutil.rmtree(parent_dir)
    os.mkdir(parent_dir)

    for i, model in enumerate(self.models):
      directory = self.model_name + str(i)
      path = os.path.join(parent_dir, directory)
      if os.path.exists(path):
          shutil.rmtree(path)
      os.mkdir(path)
      model.save(path)

  def load(self, filepath):
    parent_dir = filepath
    for i in range(self.n_splits):
      directory = self.model_name + str(i)
      path = os.path.join(parent_dir, directory)
      if os.path.exists(path):
        self.models[i] = tfk.models.load_model(path)

# %% [markdown]
# # Training

# %%
# %cd ./andrea/Conv1D
# Out:
# /content/drive/MyDrive/ANN2DL_HW2_Shared/andrea/Conv1D

# %%
# Create folders and callbacks and fit
cbs = create_folders_and_callbacks(model_name, experiments_name)
cbs.append([tfk.callbacks.EarlyStopping(monitor='val_accuracy', mode='max', patience=patience1, restore_best_weights=True),
        tfk.callbacks.ReduceLROnPlateau(monitor='val_accuracy', mode='max', patience=patience_plateau, factor=lr_factor, min_lr=min_lr)])

if noise:
  ds = AWGNTrain(X_train, y_train, batch_size)

  history = model.fit(
      ds,
      batch_size = batch_size,
      epochs = epochs,
      validation_data=(X_val, y_val),
      callbacks = cbs,
      shuffle = True
  ).history
  
else:
  # Train the model
  history = model.fit(
      x = X_train,
      y = y_train,
      batch_size = batch_size,
      epochs = epochs,
      validation_data=(X_val, y_val),
      callbacks = cbs,
      shuffle = True
  ).history
# Out:
# Epoch 1/200
# 65/65 [==============================] - 11s 25ms/step - loss: 55.8415 - accuracy: 0.0880 - val_loss: 5.9177 - val_accuracy: 0.0988 - lr: 0.0010
# Epoch 2/200
# 65/65 [==============================] - 1s 13ms/step - loss: 4.2145 - accuracy: 0.1661 - val_loss: 3.2858 - val_accuracy: 0.0782 - lr: 0.0010
# Epoch 3/200
# 65/65 [==============================] - 1s 14ms/step - loss: 2.4905 - accuracy: 0.2289 - val_loss: 2.4622 - val_accuracy: 0.1687 - lr: 0.0010
# Epoch 4/200
# 65/65 [==============================] - 1s 12ms/step - loss: 2.0942 - accuracy: 0.3316 - val_loss: 2.3843 - val_accuracy: 0.2140 - lr: 0.0010
# Epoch 5/200
# 65/65 [==============================] - 1s 12ms/step - loss: 2.4610 - accuracy: 0.2952 - val_loss: 3.0213 - val_accuracy: 0.2058 - lr: 0.0010
# Epoch 6/200
# 65/65 [==============================] - 1s 13ms/step - loss: 2.5887 - accuracy: 0.2454 - val_loss: 2.3490 - val_accuracy: 0.3457 - lr: 0.0010
# Epoch 7/200
# 65/65 [==============================] - 1s 12ms/step - loss: 2.0639 - accuracy: 0.3252 - val_loss: 2.2171 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 8/200
# 65/65 [==============================] - 1s 13ms/step - loss: 1.9042 - accuracy: 0.3994 - val_loss: 2.0350 - val_accuracy: 0.4115 - lr: 0.0010
# Epoch 9/200
# 65/65 [==============================] - 1s 13ms/step - loss: 2.2534 - accuracy: 0.3253 - val_loss: 2.1729 - val_accuracy: 0.2840 - lr: 0.0010
# Epoch 10/200
# 65/65 [==============================] - 1s 12ms/step - loss: 2.0422 - accuracy: 0.3491 - val_loss: 2.1518 - val_accuracy: 0.3128 - lr: 0.0010
# Epoch 11/200
# 65/65 [==============================] - 1s 12ms/step - loss: 2.3018 - accuracy: 0.3355 - val_loss: 2.5010 - val_accuracy: 0.2593 - lr: 0.0010
# Epoch 12/200
# 65/65 [==============================] - 1s 13ms/step - loss: 2.5774 - accuracy: 0.2881 - val_loss: 2.8494 - val_accuracy: 0.1276 - lr: 0.0010
# Epoch 13/200
# 65/65 [==============================] - 1s 12ms/step - loss: 2.3735 - accuracy: 0.2845 - val_loss: 2.2338 - val_accuracy: 0.2305 - lr: 0.0010
# Epoch 14/200
# 65/65 [==============================] - 1s 12ms/step - loss: 1.9544 - accuracy: 0.3398 - val_loss: 2.1257 - val_accuracy: 0.2675 - lr: 5.0000e-04
# Epoch 15/200
# 65/65 [==============================] - 1s 13ms/step - loss: 1.8266 - accuracy: 0.3814 - val_loss: 1.9737 - val_accuracy: 0.2922 - lr: 5.0000e-04
# Epoch 16/200
# 65/65 [==============================] - 1s 12ms/step - loss: 1.9953 - accuracy: 0.3876 - val_loss: 2.1769 - val_accuracy: 0.3086 - lr: 5.0000e-04
# Epoch 17/200
# 65/65 [==============================] - 1s 12ms/step - loss: 2.1704 - accuracy: 0.3626 - val_loss: 5.0549 - val_accuracy: 0.2263 - lr: 5.0000e-04
# Epoch 18/200
# 65/65 [==============================] - 1s 13ms/step - loss: 2.0364 - accuracy: 0.3783 - val_loss: 1.9744 - val_accuracy: 0.3333 - lr: 5.0000e-04
# Epoch 19/200
# 65/65 [==============================] - 1s 12ms/step - loss: 1.7492 - accuracy: 0.4049 - val_loss: 1.8256 - val_accuracy: 0.3416 - lr: 2.5000e-04
# Epoch 20/200
# 65/65 [==============================] - 1s 12ms/step - loss: 1.6394 - accuracy: 0.4395 - val_loss: 1.7827 - val_accuracy: 0.3580 - lr: 2.5000e-04
# Epoch 21/200
# 65/65 [==============================] - 1s 13ms/step - loss: 1.5975 - accuracy: 0.4596 - val_loss: 2.1069 - val_accuracy: 0.3663 - lr: 2.5000e-04
# Epoch 22/200
# 65/65 [==============================] - 1s 12ms/step - loss: 1.8584 - accuracy: 0.4305 - val_loss: 1.9085 - val_accuracy: 0.3004 - lr: 2.5000e-04
# Epoch 23/200
# 65/65 [==============================] - 1s 12ms/step - loss: 1.5195 - accuracy: 0.4915 - val_loss: 1.6442 - val_accuracy: 0.3745 - lr: 2.5000e-04
# Epoch 24/200
# 65/65 [==============================] - 1s 13ms/step - loss: 1.4211 - accuracy: 0.5261 - val_loss: 1.6082 - val_accuracy: 0.4074 - lr: 1.2500e-04
# Epoch 25/200
# 65/65 [==============================] - 1s 12ms/step - loss: 1.4304 - accuracy: 0.5349 - val_loss: 2.0710 - val_accuracy: 0.3539 - lr: 1.2500e-04
# Epoch 26/200
# 65/65 [==============================] - 1s 12ms/step - loss: 1.7235 - accuracy: 0.4722 - val_loss: 1.8058 - val_accuracy: 0.3786 - lr: 1.2500e-04
# Epoch 27/200
# 65/65 [==============================] - 1s 13ms/step - loss: 1.4705 - accuracy: 0.5188 - val_loss: 1.6704 - val_accuracy: 0.4033 - lr: 1.2500e-04
# Epoch 28/200
# 65/65 [==============================] - 1s 12ms/step - loss: 1.3876 - accuracy: 0.5372 - val_loss: 1.5925 - val_accuracy: 0.4321 - lr: 1.2500e-04
# Epoch 29/200
# 65/65 [==============================] - 1s 12ms/step - loss: 1.3365 - accuracy: 0.5443 - val_loss: 1.5605 - val_accuracy: 0.4321 - lr: 1.2500e-04
# Epoch 30/200
# 65/65 [==============================] - 1s 13ms/step - loss: 1.3141 - accuracy: 0.5596 - val_loss: 1.5244 - val_accuracy: 0.4280 - lr: 1.2500e-04
# Epoch 31/200
# 65/65 [==============================] - 1s 12ms/step - loss: 1.2486 - accuracy: 0.5699 - val_loss: 1.5649 - val_accuracy: 0.4280 - lr: 1.2500e-04
# Epoch 32/200
# 65/65 [==============================] - 1s 12ms/step - loss: 1.2347 - accuracy: 0.5686 - val_loss: 1.5136 - val_accuracy: 0.4280 - lr: 1.2500e-04
# Epoch 33/200
# 65/65 [==============================] - 1s 13ms/step - loss: 1.1944 - accuracy: 0.5801 - val_loss: 1.5412 - val_accuracy: 0.4527 - lr: 1.2500e-04
# Epoch 34/200
# 65/65 [==============================] - 1s 13ms/step - loss: 1.1607 - accuracy: 0.5959 - val_loss: 1.4480 - val_accuracy: 0.4815 - lr: 1.2500e-04
# Epoch 35/200
# 65/65 [==============================] - 1s 13ms/step - loss: 1.1408 - accuracy: 0.6089 - val_loss: 1.4649 - val_accuracy: 0.4609 - lr: 1.2500e-04
# Epoch 36/200
# 65/65 [==============================] - 1s 13ms/step - loss: 1.1026 - accuracy: 0.6096 - val_loss: 1.5540 - val_accuracy: 0.4774 - lr: 1.2500e-04
# Epoch 37/200
# 65/65 [==============================] - 1s 12ms/step - loss: 1.0870 - accuracy: 0.6174 - val_loss: 1.5071 - val_accuracy: 0.4362 - lr: 1.2500e-04
# Epoch 38/200
# 65/65 [==============================] - 1s 13ms/step - loss: 1.0583 - accuracy: 0.6305 - val_loss: 1.7114 - val_accuracy: 0.4280 - lr: 1.2500e-04
# Epoch 39/200
# 65/65 [==============================] - 1s 13ms/step - loss: 1.0388 - accuracy: 0.6416 - val_loss: 1.5364 - val_accuracy: 0.5021 - lr: 1.2500e-04
# Epoch 40/200
# 65/65 [==============================] - 1s 13ms/step - loss: 0.9975 - accuracy: 0.6456 - val_loss: 1.5625 - val_accuracy: 0.5185 - lr: 1.2500e-04
# Epoch 41/200
# 65/65 [==============================] - 1s 13ms/step - loss: 0.9811 - accuracy: 0.6589 - val_loss: 1.7102 - val_accuracy: 0.5185 - lr: 1.2500e-04
# Epoch 42/200
# 65/65 [==============================] - 1s 13ms/step - loss: 0.9509 - accuracy: 0.6717 - val_loss: 1.6340 - val_accuracy: 0.5021 - lr: 1.2500e-04
# Epoch 43/200
# 65/65 [==============================] - 1s 13ms/step - loss: 0.9837 - accuracy: 0.6497 - val_loss: 1.5164 - val_accuracy: 0.4979 - lr: 1.2500e-04
# Epoch 44/200
# 65/65 [==============================] - 1s 12ms/step - loss: 0.9449 - accuracy: 0.6739 - val_loss: 1.7116 - val_accuracy: 0.5144 - lr: 1.2500e-04
# Epoch 45/200
# 65/65 [==============================] - 1s 13ms/step - loss: 0.8938 - accuracy: 0.6968 - val_loss: 1.5373 - val_accuracy: 0.5226 - lr: 1.2500e-04
# Epoch 46/200
# 65/65 [==============================] - 1s 13ms/step - loss: 0.8872 - accuracy: 0.6937 - val_loss: 1.7080 - val_accuracy: 0.5144 - lr: 1.2500e-04
# Epoch 47/200
# 65/65 [==============================] - 1s 13ms/step - loss: 1.0179 - accuracy: 0.6757 - val_loss: 1.6053 - val_accuracy: 0.5350 - lr: 1.2500e-04
# Epoch 48/200
# 65/65 [==============================] - 1s 13ms/step - loss: 0.8622 - accuracy: 0.6966 - val_loss: 1.5862 - val_accuracy: 0.5350 - lr: 1.2500e-04
# Epoch 49/200
# 65/65 [==============================] - 1s 18ms/step - loss: 0.8372 - accuracy: 0.7096 - val_loss: 1.6135 - val_accuracy: 0.5062 - lr: 1.2500e-04
# Epoch 50/200
# 65/65 [==============================] - 1s 18ms/step - loss: 0.9149 - accuracy: 0.7028 - val_loss: 1.9978 - val_accuracy: 0.4033 - lr: 1.2500e-04
# Epoch 51/200
# 65/65 [==============================] - 1s 13ms/step - loss: 0.8394 - accuracy: 0.7158 - val_loss: 1.5692 - val_accuracy: 0.5103 - lr: 1.2500e-04
# Epoch 52/200
# 65/65 [==============================] - 1s 13ms/step - loss: 0.7788 - accuracy: 0.7379 - val_loss: 2.1091 - val_accuracy: 0.5309 - lr: 1.2500e-04
# Epoch 53/200
# 65/65 [==============================] - 1s 12ms/step - loss: 1.0590 - accuracy: 0.6874 - val_loss: 1.4180 - val_accuracy: 0.5144 - lr: 6.2500e-05
# Epoch 54/200
# 65/65 [==============================] - 1s 13ms/step - loss: 0.7563 - accuracy: 0.7425 - val_loss: 1.4539 - val_accuracy: 0.5432 - lr: 6.2500e-05
# Epoch 55/200
# 65/65 [==============================] - 1s 13ms/step - loss: 0.7265 - accuracy: 0.7538 - val_loss: 1.5676 - val_accuracy: 0.5391 - lr: 6.2500e-05
# Epoch 56/200
# 65/65 [==============================] - 1s 13ms/step - loss: 0.7211 - accuracy: 0.7543 - val_loss: 1.5291 - val_accuracy: 0.5597 - lr: 6.2500e-05
# Epoch 57/200
# 65/65 [==============================] - 1s 13ms/step - loss: 0.6990 - accuracy: 0.7604 - val_loss: 1.4045 - val_accuracy: 0.5844 - lr: 6.2500e-05
# Epoch 58/200
# 65/65 [==============================] - 1s 12ms/step - loss: 0.6812 - accuracy: 0.7667 - val_loss: 1.4730 - val_accuracy: 0.5514 - lr: 6.2500e-05
# Epoch 59/200
# 65/65 [==============================] - 1s 13ms/step - loss: 0.6808 - accuracy: 0.7653 - val_loss: 1.4902 - val_accuracy: 0.5802 - lr: 6.2500e-05
# Epoch 60/200
# 65/65 [==============================] - 1s 13ms/step - loss: 0.6758 - accuracy: 0.7674 - val_loss: 1.5326 - val_accuracy: 0.5761 - lr: 6.2500e-05
# Epoch 61/200
# 65/65 [==============================] - 1s 13ms/step - loss: 0.6732 - accuracy: 0.7691 - val_loss: 1.5063 - val_accuracy: 0.5926 - lr: 6.2500e-05
# Epoch 62/200
# 65/65 [==============================] - 1s 13ms/step - loss: 0.6463 - accuracy: 0.7783 - val_loss: 1.5270 - val_accuracy: 0.5885 - lr: 6.2500e-05
# Epoch 63/200
# 65/65 [==============================] - 1s 13ms/step - loss: 0.6478 - accuracy: 0.7753 - val_loss: 1.5709 - val_accuracy: 0.5679 - lr: 6.2500e-05
# Epoch 64/200
# 65/65 [==============================] - 1s 13ms/step - loss: 0.6305 - accuracy: 0.7882 - val_loss: 1.5384 - val_accuracy: 0.5802 - lr: 6.2500e-05
# Epoch 65/200
# 65/65 [==============================] - 1s 13ms/step - loss: 0.6169 - accuracy: 0.7858 - val_loss: 1.5792 - val_accuracy: 0.5926 - lr: 6.2500e-05
# Epoch 66/200
# 65/65 [==============================] - 1s 13ms/step - loss: 0.6198 - accuracy: 0.7897 - val_loss: 1.5704 - val_accuracy: 0.5802 - lr: 6.2500e-05
# Epoch 67/200
# 65/65 [==============================] - 1s 12ms/step - loss: 0.5978 - accuracy: 0.7997 - val_loss: 1.6121 - val_accuracy: 0.5926 - lr: 3.1250e-05
# Epoch 68/200
# 65/65 [==============================] - 1s 18ms/step - loss: 0.5885 - accuracy: 0.7986 - val_loss: 1.7327 - val_accuracy: 0.5638 - lr: 3.1250e-05
# Epoch 69/200
# 65/65 [==============================] - 1s 13ms/step - loss: 0.5853 - accuracy: 0.7947 - val_loss: 1.7085 - val_accuracy: 0.5679 - lr: 3.1250e-05
# Epoch 70/200
# 65/65 [==============================] - 1s 13ms/step - loss: 0.5764 - accuracy: 0.8035 - val_loss: 1.6796 - val_accuracy: 0.5720 - lr: 3.1250e-05
# Epoch 71/200
# 65/65 [==============================] - 1s 13ms/step - loss: 0.5692 - accuracy: 0.8062 - val_loss: 1.7773 - val_accuracy: 0.5720 - lr: 3.1250e-05
# Epoch 72/200
# 65/65 [==============================] - 1s 13ms/step - loss: 0.5569 - accuracy: 0.8063 - val_loss: 1.6740 - val_accuracy: 0.5802 - lr: 1.5625e-05
# Epoch 73/200
# 65/65 [==============================] - 1s 13ms/step - loss: 0.5507 - accuracy: 0.8124 - val_loss: 1.6886 - val_accuracy: 0.5844 - lr: 1.5625e-05
# Epoch 74/200
# 65/65 [==============================] - 1s 13ms/step - loss: 0.5483 - accuracy: 0.8155 - val_loss: 1.6851 - val_accuracy: 0.5802 - lr: 1.5625e-05
# Epoch 75/200
# 65/65 [==============================] - 1s 13ms/step - loss: 0.5481 - accuracy: 0.8174 - val_loss: 1.6945 - val_accuracy: 0.5844 - lr: 1.5625e-05
# Epoch 76/200
# 65/65 [==============================] - 1s 13ms/step - loss: 0.5507 - accuracy: 0.8151 - val_loss: 1.7051 - val_accuracy: 0.5844 - lr: 1.5625e-05
# Epoch 77/200
# 65/65 [==============================] - 1s 13ms/step - loss: 0.5435 - accuracy: 0.8131 - val_loss: 1.7037 - val_accuracy: 0.5844 - lr: 1.0000e-05
# Epoch 78/200
# 65/65 [==============================] - 1s 12ms/step - loss: 0.5379 - accuracy: 0.8201 - val_loss: 1.6952 - val_accuracy: 0.5844 - lr: 1.0000e-05
# Epoch 79/200
# 65/65 [==============================] - 1s 13ms/step - loss: 0.5358 - accuracy: 0.8217 - val_loss: 1.7016 - val_accuracy: 0.5802 - lr: 1.0000e-05
# Epoch 80/200
# 65/65 [==============================] - 1s 13ms/step - loss: 0.5331 - accuracy: 0.8182 - val_loss: 1.6781 - val_accuracy: 0.5761 - lr: 1.0000e-05
# Epoch 81/200
# 65/65 [==============================] - 1s 13ms/step - loss: 0.5318 - accuracy: 0.8201 - val_loss: 1.6876 - val_accuracy: 0.5802 - lr: 1.0000e-05

# %%
best_epoch = np.argmax(history['val_accuracy'])
plt.figure(figsize=(17,4))
plt.plot(history['loss'], label='Training loss', alpha=.8, color='#ff7f0e')
plt.plot(history['val_loss'], label='Validation loss', alpha=.9, color='#5a9aa5')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
plt.title('Categorical Crossentropy')
plt.legend()
plt.grid(alpha=.3)
plt.show()

plt.figure(figsize=(17,4))
plt.plot(history['accuracy'], label='Training accuracy', alpha=.8, color='#ff7f0e')
plt.plot(history['val_accuracy'], label='Validation accuracy', alpha=.9, color='#5a9aa5')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
plt.title('Accuracy')
plt.legend()
plt.grid(alpha=.3)
plt.show()

plt.figure(figsize=(17,4))
plt.plot(history['lr'], label='Learning Rate', alpha=.8, color='#ff7f0e')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
plt.legend()
plt.grid(alpha=.3)
plt.show()

# %%
# Predict the test set with the RNN
predictions = model.predict(X_val)
predictions.shape
# Out:
# 8/8 [==============================] - 0s 13ms/step
# (243, 12)

# %%
# Compute the confusion matrix
cm = confusion_matrix(np.argmax(y_val, axis=-1), np.argmax(predictions, axis=-1))

# Compute the classification metrics
accuracy = accuracy_score(np.argmax(y_val, axis=-1), np.argmax(predictions, axis=-1))
precision = precision_score(np.argmax(y_val, axis=-1), np.argmax(predictions, axis=-1), average='macro')
recall = recall_score(np.argmax(y_val, axis=-1), np.argmax(predictions, axis=-1), average='macro')
f1 = f1_score(np.argmax(y_val, axis=-1), np.argmax(predictions, axis=-1), average='macro')
print('Accuracy:',accuracy.round(4))
print('Precision:',precision.round(4))
print('Recall:',recall.round(4))
print('F1:',f1.round(4))

# Plot the confusion matrix
plt.figure(figsize=(10,8))
sns.heatmap(cm.T, cmap='Blues', xticklabels=list(label_mapping), yticklabels=list(label_mapping), annot=True)
plt.xlabel('True labels')
plt.ylabel('Predicted labels')
plt.show()
# Out:
# Accuracy: 0.5926
# Precision: 0.5661
# Recall: 0.6633
# F1: 0.5719

# %%
f1s = f1_score(np.argmax(y_val, axis=-1), np.argmax(predictions, axis=-1), average=None)

fig = plt.figure(figsize=(21, 5))
plt.bar(np.arange(12), f1s, width=1, edgecolor="white", tick_label=list(label_mapping))

plt.show()

# %% [markdown]
# # Save the model

# %%
#model.save(model_name)
#model.load(model_name)
