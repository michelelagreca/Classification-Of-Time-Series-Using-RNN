# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/ANN2DL_HW2_Shared
# Out:
# /content/drive/MyDrive/ANN2DL_HW2_Shared

# %%
import tensorflow as tf
import numpy as np
import os
import random
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.rc('font', size=16) 
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_class_weight
from imblearn.over_sampling import RandomOverSampler
import warnings
import logging

tfk = tf.keras
tfkl = tf.keras.layers
print(tf.__version__)
# Out:
# 2.9.2

# %%
# Random seed for reproducibility
seed = 42

random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)

# %%
x_file_path = "./original_data/x_train.npy"
y_file_path = "./original_data/y_train.npy"

X = np.load(x_file_path)
y = np.load(y_file_path)

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, random_state=seed)
n_dimensions = X_train.shape[2]
X_train.shape, y_train.shape, X_val.shape, y_val.shape
# Out:
# ((1943, 36, 6), (1943,), (486, 36, 6), (486,))

# %%
label_mapping = {
    "Wish",
    "Another",
    "Comfortably",
    "Money",
    "Breathe",
    "Time",
    "Brain",
    "Echoes",
    "Wearing",
    "Sorrow",
    "Hey",
    "Shine"
}

# %%
def normalize(X_train, axis, norm_type='no_norm'):
  axs = [0,1,2]
  axs.remove(axis)
  axs=tuple(axs)

  means = np.mean(X_train, axis=axs)
  stds = np.std(X_train, axis=axs)
  mins = np.min(X_train, axis=axs)
  maxs = np.max(X_train, axis=axs)

  params = {
      "means": means,
      "stds": stds,
      "mins": mins,
      "maxs": maxs
  }
  
  if norm_type=='standard':
    X_std_train = []
    
    for i in range(X_train.shape[axis]):
      data = np.take(X_train, i, axis=axis)
      data = (data - means[i]) / stds[i]
      X_std_train.append(data)

    X_std_train = tuple(X_std_train)
    X_std_train = np.stack(X_std_train, axis=axis)

    return X_std_train, params


  elif norm_type=='minmax':
    X_norm_train = []
    
    for i in range(X_train.shape[axis]):
      data = np.take(X_train, i, axis=axis)
      data = (data - mins[i]) / (maxs[i] - mins[i])
      X_norm_train.append(data)

    X_norm_train = tuple(X_norm_train)
    X_norm_train = np.stack(X_norm_train, axis=axis)

    return X_norm_train, params

  else:
    return X_train, params

# %%
def normalize_test(X, params, axis, norm_type='no_norm'):
  
  if norm_type=='standard':
    X_std_val = []

    means = params["means"]
    stds = params["stds"]
    mins = params["mins"]
    maxs = params["maxs"]

    for i in range(X.shape[axis]):
      data = np.take(X, i, axis=axis)
      data = (data - means[i]) / stds[i]
      X_std_val.append(data)

    X_std_val = tuple(X_std_val)
    X_std_val = np.stack(X_std_val, axis=axis)

    return X_std_val

  elif norm_type=='minmax':
    X_norm_val = []
    
    for i in range(X.shape[axis]):
      data = np.take(X, i, axis=axis)
      data = (data - mins[i]) / (maxs[i] - min)
      X_norm_val.append(data)

    X_norm_val = tuple(X_norm_val)
    X_norm_val = np.stack(X_norm_val, axis=axis)

    return X_norm_val

  else:
    return X

# %%
axis = 2
n_t = 'standard'

X_train, p = normalize(X_train, axis, norm_type=n_t)
X_val = normalize_test(X_val, p, axis, norm_type=n_t)

# %%
class_weights = compute_class_weight(class_weight='balanced', classes=np.unique(y), y=y)

fig = plt.figure(figsize=(21, 5))
plt.bar(np.arange(12), class_weights, width=1, edgecolor="white", tick_label=list(label_mapping))
plt.show()

# %%
class_weights = dict(zip(np.arange(12), class_weights))
class_weights
# Out:
# {0: 5.953431372549019,
#  1: 1.6456639566395663,
#  2: 0.7496913580246913,
#  3: 0.5312773403324584,
#  4: 3.264784946236559,
#  5: 1.3229847494553377,
#  6: 0.6466986155484558,
#  7: 2.9767156862745097,
#  8: 1.6868055555555554,
#  9: 0.2605105105105105,
#  10: 2.628787878787879,
#  11: 3.968954248366013}

# %%
y_train = tfk.utils.to_categorical(y_train)
y_val = tfk.utils.to_categorical(y_val)
y_train.shape, y_val.shape
# Out:
# ((1943, 12), (486, 12))

# %%
# Utility function to create folders and callbacks for training
from datetime import datetime

def create_folders_and_callbacks(model_name, experiments_name):

  exps_dir = os.path.join(experiments_name)
  if not os.path.exists(exps_dir):
      os.makedirs(exps_dir)

  now = datetime.now().strftime('%b%d_%H-%M-%S')

  exp_dir = os.path.join(exps_dir, model_name + '_' + str(now))
  if not os.path.exists(exp_dir):
      os.makedirs(exp_dir)
      
  callbacks = []

  # Model checkpoint
  # ----------------
  ckpt_dir = os.path.join(exp_dir, 'ckpts')
  if not os.path.exists(ckpt_dir):
      os.makedirs(ckpt_dir)

  ckpt_callback = tf.keras.callbacks.ModelCheckpoint(filepath=os.path.join(ckpt_dir, 'cp.ckpt'), 
                                                     save_weights_only=True, # True to save only weights
                                                     save_best_only=False) # True to save only the best epoch 
  callbacks.append(ckpt_callback)

  # Visualize Learning on Tensorboard
  # ---------------------------------
  tb_dir = os.path.join(exp_dir, 'tb_logs')
  if not os.path.exists(tb_dir):
      os.makedirs(tb_dir)
      
  # By default shows losses and metrics for both training and validation
  tb_callback = tf.keras.callbacks.TensorBoard(log_dir=tb_dir, 
                                               profile_batch=0,
                                               histogram_freq=1)  # if > 0 (epochs) shows weights histograms
  callbacks.append(tb_callback)

  return callbacks

# %%
def build_classifier(input_shape, classes, model_name, lr=0.001):
    # Build the neural network layer by layer
    input_layer = tfkl.Input(shape=input_shape, name='Input')

    # Feature extractor
    cnn = tfkl.Conv1D(128,5,padding='same',activation='relu')(input_layer) # we will have the same samples in the next layer, we dont loose the temporality
    cnn = tfkl.MaxPooling1D()(cnn)

    cnn = tfkl.Conv1D(256,5,padding='same',activation='relu')(cnn)
    cnn = tfkl.MaxPooling1D()(cnn)

    cnn = tfkl.Conv1D(256,5,padding='same',activation='relu')(cnn)
    cnn = tfkl.MaxPooling1D()(cnn)

    cnn = tfkl.Conv1D(256,5,padding='same',activation='relu')(cnn)
    gap = tfkl.GlobalAveragePooling1D()(cnn)

    # Classifier
    classifier = tfkl.Dense(256, activation='relu')(gap)
    
    output_layer = tfkl.Dense(12, activation='softmax')(classifier)

    # Connect input and output through the Model class
    model = tfk.Model(inputs=input_layer, outputs=output_layer, name=model_name)

    # Compile the model
    model.compile(loss=tfk.losses.CategoricalCrossentropy(), optimizer=tfk.optimizers.Adam(lr), metrics='accuracy')

    # Return the model
    return model

# %%
model_name = "Conv1D_with_std_norm_axis_2"
experiments_name = "Weighted_loss_normalization"

input_shape = X_train.shape[1:]
classes = y_train.shape[-1]
batch_size = 128
epochs = 200

patience1 = 25
patience_plateau = 5
min_lr = 1e-5
lr_factor = 0.5

# %%
model = build_classifier(input_shape, classes, model_name)
model.summary()
# Out:
# Model: "Conv1D_with_std_norm_axis_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 36, 6)]           0
#
#  conv1d_8 (Conv1D)           (None, 36, 128)           3968
#
#  max_pooling1d_6 (MaxPooling  (None, 18, 128)          0
#  1D)
#
#  conv1d_9 (Conv1D)           (None, 18, 256)           164096
#
#  max_pooling1d_7 (MaxPooling  (None, 9, 256)           0
#  1D)
#
#  conv1d_10 (Conv1D)          (None, 9, 256)            327936
#
#  max_pooling1d_8 (MaxPooling  (None, 4, 256)           0
#  1D)
#
#  conv1d_11 (Conv1D)          (None, 4, 256)            327936
#
#  global_average_pooling1d_2   (None, 256)              0
#  (GlobalAveragePooling1D)
#
#  dense_4 (Dense)             (None, 256)               65792
#
#  dense_5 (Dense)             (None, 12)                3084
#
# =================================================================
# Total params: 892,812
# Trainable params: 892,812
# Non-trainable params: 0
# _________________________________________________________________

# %%
# %cd ./andrea/Conv1D
# Out:
# /content/drive/MyDrive/ANN2DL_HW2_Shared/andrea/Conv1D

# %%
# Create folders and callbacks and fit
cbs = create_folders_and_callbacks(model_name, experiments_name)
cbs.append([tfk.callbacks.EarlyStopping(monitor='val_accuracy', mode='max', patience=patience1, restore_best_weights=True),
        tfk.callbacks.ReduceLROnPlateau(monitor='val_accuracy', mode='max', patience=patience_plateau, factor=lr_factor, min_lr=min_lr)])

# Train the model
history = model.fit(
    x = X_train,
    y = y_train,
    batch_size = batch_size,
    epochs = epochs,
    validation_data=(X_val, y_val),
    callbacks = cbs,
    class_weight = class_weights
).history
# Out:
# Epoch 1/200
# 16/16 [==============================] - 2s 54ms/step - loss: 2.4664 - accuracy: 0.0422 - val_loss: 2.4102 - val_accuracy: 0.2037 - lr: 0.0010
# Epoch 2/200
# 16/16 [==============================] - 0s 26ms/step - loss: 2.2930 - accuracy: 0.2928 - val_loss: 2.3778 - val_accuracy: 0.3395 - lr: 0.0010
# Epoch 3/200
# 16/16 [==============================] - 0s 27ms/step - loss: 2.1998 - accuracy: 0.3562 - val_loss: 2.2149 - val_accuracy: 0.3745 - lr: 0.0010
# Epoch 4/200
# 16/16 [==============================] - 0s 25ms/step - loss: 2.1024 - accuracy: 0.2856 - val_loss: 2.2102 - val_accuracy: 0.1132 - lr: 0.0010
# Epoch 5/200
# 16/16 [==============================] - 0s 26ms/step - loss: 2.0763 - accuracy: 0.1199 - val_loss: 2.1645 - val_accuracy: 0.1111 - lr: 0.0010
# Epoch 6/200
# 16/16 [==============================] - 0s 29ms/step - loss: 1.9030 - accuracy: 0.3788 - val_loss: 1.9853 - val_accuracy: 0.4280 - lr: 0.0010
# Epoch 7/200
# 16/16 [==============================] - 0s 27ms/step - loss: 1.7608 - accuracy: 0.2748 - val_loss: 2.0378 - val_accuracy: 0.2140 - lr: 0.0010
# Epoch 8/200
# 16/16 [==============================] - 0s 26ms/step - loss: 1.6683 - accuracy: 0.3567 - val_loss: 1.9123 - val_accuracy: 0.2881 - lr: 0.0010
# Epoch 9/200
# 16/16 [==============================] - 0s 29ms/step - loss: 1.7182 - accuracy: 0.2501 - val_loss: 2.0930 - val_accuracy: 0.2387 - lr: 0.0010
# Epoch 10/200
# 16/16 [==============================] - 0s 26ms/step - loss: 1.7725 - accuracy: 0.2609 - val_loss: 1.9298 - val_accuracy: 0.2037 - lr: 0.0010
# Epoch 11/200
# 16/16 [==============================] - 0s 29ms/step - loss: 1.5715 - accuracy: 0.2532 - val_loss: 1.8699 - val_accuracy: 0.2860 - lr: 0.0010
# Epoch 12/200
# 16/16 [==============================] - 0s 29ms/step - loss: 1.4558 - accuracy: 0.3438 - val_loss: 1.7437 - val_accuracy: 0.3230 - lr: 5.0000e-04
# Epoch 13/200
# 16/16 [==============================] - 0s 28ms/step - loss: 1.3569 - accuracy: 0.3757 - val_loss: 1.6875 - val_accuracy: 0.3786 - lr: 5.0000e-04
# Epoch 14/200
# 16/16 [==============================] - 0s 26ms/step - loss: 1.3098 - accuracy: 0.3464 - val_loss: 1.6321 - val_accuracy: 0.3909 - lr: 5.0000e-04
# Epoch 15/200
# 16/16 [==============================] - 0s 28ms/step - loss: 1.2566 - accuracy: 0.4071 - val_loss: 1.6617 - val_accuracy: 0.3663 - lr: 5.0000e-04
# Epoch 16/200
# 16/16 [==============================] - 0s 29ms/step - loss: 1.2105 - accuracy: 0.3870 - val_loss: 1.5762 - val_accuracy: 0.4300 - lr: 5.0000e-04
# Epoch 17/200
# 16/16 [==============================] - 0s 28ms/step - loss: 1.2712 - accuracy: 0.4205 - val_loss: 1.7128 - val_accuracy: 0.3189 - lr: 5.0000e-04
# Epoch 18/200
# 16/16 [==============================] - 0s 30ms/step - loss: 1.1993 - accuracy: 0.4102 - val_loss: 1.5954 - val_accuracy: 0.4671 - lr: 5.0000e-04
# Epoch 19/200
# 16/16 [==============================] - 0s 27ms/step - loss: 1.1755 - accuracy: 0.4092 - val_loss: 1.7985 - val_accuracy: 0.3333 - lr: 5.0000e-04
# Epoch 20/200
# 16/16 [==============================] - 0s 28ms/step - loss: 1.2571 - accuracy: 0.4035 - val_loss: 1.6075 - val_accuracy: 0.3951 - lr: 5.0000e-04
# Epoch 21/200
# 16/16 [==============================] - 0s 28ms/step - loss: 1.1376 - accuracy: 0.4086 - val_loss: 1.5676 - val_accuracy: 0.3663 - lr: 5.0000e-04
# Epoch 22/200
# 16/16 [==============================] - 0s 26ms/step - loss: 1.0753 - accuracy: 0.4786 - val_loss: 1.5511 - val_accuracy: 0.4095 - lr: 5.0000e-04
# Epoch 23/200
# 16/16 [==============================] - 0s 28ms/step - loss: 1.5785 - accuracy: 0.4581 - val_loss: 1.7808 - val_accuracy: 0.3416 - lr: 5.0000e-04
# Epoch 24/200
# 16/16 [==============================] - 0s 28ms/step - loss: 1.3655 - accuracy: 0.3726 - val_loss: 1.7017 - val_accuracy: 0.3477 - lr: 2.5000e-04
# Epoch 25/200
# 16/16 [==============================] - 0s 27ms/step - loss: 1.2066 - accuracy: 0.4375 - val_loss: 1.5471 - val_accuracy: 0.4218 - lr: 2.5000e-04
# Epoch 26/200
# 16/16 [==============================] - 0s 26ms/step - loss: 1.1231 - accuracy: 0.4936 - val_loss: 1.4979 - val_accuracy: 0.4074 - lr: 2.5000e-04
# Epoch 27/200
# 16/16 [==============================] - 0s 28ms/step - loss: 1.0646 - accuracy: 0.4864 - val_loss: 1.4877 - val_accuracy: 0.4012 - lr: 2.5000e-04
# Epoch 28/200
# 16/16 [==============================] - 0s 27ms/step - loss: 1.0280 - accuracy: 0.4683 - val_loss: 1.4949 - val_accuracy: 0.4259 - lr: 2.5000e-04
# Epoch 29/200
# 16/16 [==============================] - 0s 26ms/step - loss: 0.9950 - accuracy: 0.4838 - val_loss: 1.4260 - val_accuracy: 0.4568 - lr: 1.2500e-04
# Epoch 30/200
# 16/16 [==============================] - 0s 30ms/step - loss: 0.9853 - accuracy: 0.4817 - val_loss: 1.4967 - val_accuracy: 0.4198 - lr: 1.2500e-04
# Epoch 31/200
# 16/16 [==============================] - 0s 30ms/step - loss: 0.9643 - accuracy: 0.4745 - val_loss: 1.3784 - val_accuracy: 0.4753 - lr: 1.2500e-04
# Epoch 32/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.9578 - accuracy: 0.5095 - val_loss: 1.4868 - val_accuracy: 0.4136 - lr: 1.2500e-04
# Epoch 33/200
# 16/16 [==============================] - 0s 28ms/step - loss: 0.9477 - accuracy: 0.4931 - val_loss: 1.4020 - val_accuracy: 0.4588 - lr: 1.2500e-04
# Epoch 34/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.9256 - accuracy: 0.5033 - val_loss: 1.4264 - val_accuracy: 0.4362 - lr: 1.2500e-04
# Epoch 35/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.9140 - accuracy: 0.5100 - val_loss: 1.3981 - val_accuracy: 0.4774 - lr: 1.2500e-04
# Epoch 36/200
# 16/16 [==============================] - 0s 29ms/step - loss: 0.9065 - accuracy: 0.5291 - val_loss: 1.4555 - val_accuracy: 0.4444 - lr: 1.2500e-04
# Epoch 37/200
# 16/16 [==============================] - 0s 29ms/step - loss: 0.9028 - accuracy: 0.5049 - val_loss: 1.4133 - val_accuracy: 0.4239 - lr: 1.2500e-04
# Epoch 38/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.8879 - accuracy: 0.5208 - val_loss: 1.3384 - val_accuracy: 0.4877 - lr: 1.2500e-04
# Epoch 39/200
# 16/16 [==============================] - 0s 29ms/step - loss: 0.8821 - accuracy: 0.5322 - val_loss: 1.4161 - val_accuracy: 0.4280 - lr: 1.2500e-04
# Epoch 40/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.8768 - accuracy: 0.5152 - val_loss: 1.3621 - val_accuracy: 0.4815 - lr: 1.2500e-04
# Epoch 41/200
# 16/16 [==============================] - 0s 28ms/step - loss: 0.8630 - accuracy: 0.5296 - val_loss: 1.4580 - val_accuracy: 0.4300 - lr: 1.2500e-04
# Epoch 42/200
# 16/16 [==============================] - 0s 31ms/step - loss: 0.8528 - accuracy: 0.5296 - val_loss: 1.3909 - val_accuracy: 0.4650 - lr: 1.2500e-04
# Epoch 43/200
# 16/16 [==============================] - 0s 28ms/step - loss: 0.8504 - accuracy: 0.5270 - val_loss: 1.3485 - val_accuracy: 0.4671 - lr: 1.2500e-04
# Epoch 44/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.8354 - accuracy: 0.5435 - val_loss: 1.4074 - val_accuracy: 0.4568 - lr: 6.2500e-05
# Epoch 45/200
# 16/16 [==============================] - 0s 28ms/step - loss: 0.8234 - accuracy: 0.5198 - val_loss: 1.4002 - val_accuracy: 0.4424 - lr: 6.2500e-05
# Epoch 46/200
# 16/16 [==============================] - 0s 28ms/step - loss: 0.8217 - accuracy: 0.5244 - val_loss: 1.3864 - val_accuracy: 0.4588 - lr: 6.2500e-05
# Epoch 47/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.8240 - accuracy: 0.5461 - val_loss: 1.4108 - val_accuracy: 0.4527 - lr: 6.2500e-05
# Epoch 48/200
# 16/16 [==============================] - 1s 38ms/step - loss: 0.8174 - accuracy: 0.5430 - val_loss: 1.4094 - val_accuracy: 0.4588 - lr: 6.2500e-05
# Epoch 49/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.8064 - accuracy: 0.5419 - val_loss: 1.3735 - val_accuracy: 0.4712 - lr: 3.1250e-05
# Epoch 50/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.8048 - accuracy: 0.5584 - val_loss: 1.3801 - val_accuracy: 0.4753 - lr: 3.1250e-05
# Epoch 51/200
# 16/16 [==============================] - 0s 28ms/step - loss: 0.8034 - accuracy: 0.5450 - val_loss: 1.3785 - val_accuracy: 0.4609 - lr: 3.1250e-05
# Epoch 52/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.7986 - accuracy: 0.5543 - val_loss: 1.3668 - val_accuracy: 0.4691 - lr: 3.1250e-05
# Epoch 53/200
# 16/16 [==============================] - 0s 29ms/step - loss: 0.7972 - accuracy: 0.5584 - val_loss: 1.3625 - val_accuracy: 0.4774 - lr: 3.1250e-05
# Epoch 54/200
# 16/16 [==============================] - 0s 28ms/step - loss: 0.7949 - accuracy: 0.5533 - val_loss: 1.3711 - val_accuracy: 0.4733 - lr: 1.5625e-05
# Epoch 55/200
# 16/16 [==============================] - 0s 29ms/step - loss: 0.7927 - accuracy: 0.5507 - val_loss: 1.3710 - val_accuracy: 0.4671 - lr: 1.5625e-05
# Epoch 56/200
# 16/16 [==============================] - 0s 29ms/step - loss: 0.7924 - accuracy: 0.5517 - val_loss: 1.3627 - val_accuracy: 0.4753 - lr: 1.5625e-05
# Epoch 57/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.7907 - accuracy: 0.5517 - val_loss: 1.3699 - val_accuracy: 0.4609 - lr: 1.5625e-05
# Epoch 58/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.7905 - accuracy: 0.5486 - val_loss: 1.3707 - val_accuracy: 0.4691 - lr: 1.5625e-05
# Epoch 59/200
# 16/16 [==============================] - 0s 29ms/step - loss: 0.7880 - accuracy: 0.5512 - val_loss: 1.3736 - val_accuracy: 0.4588 - lr: 1.0000e-05
# Epoch 60/200
# 16/16 [==============================] - 0s 29ms/step - loss: 0.7884 - accuracy: 0.5533 - val_loss: 1.3720 - val_accuracy: 0.4588 - lr: 1.0000e-05
# Epoch 61/200
# 16/16 [==============================] - 0s 28ms/step - loss: 0.7878 - accuracy: 0.5497 - val_loss: 1.3722 - val_accuracy: 0.4609 - lr: 1.0000e-05
# Epoch 62/200
# 16/16 [==============================] - 0s 28ms/step - loss: 0.7870 - accuracy: 0.5476 - val_loss: 1.3783 - val_accuracy: 0.4568 - lr: 1.0000e-05
# Epoch 63/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.7858 - accuracy: 0.5471 - val_loss: 1.3713 - val_accuracy: 0.4630 - lr: 1.0000e-05

# %%
best_epoch = np.argmax(history['val_accuracy'])
plt.figure(figsize=(17,4))
plt.plot(history['loss'], label='Training loss', alpha=.8, color='#ff7f0e')
plt.plot(history['val_loss'], label='Validation loss', alpha=.9, color='#5a9aa5')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
plt.title('Categorical Crossentropy')
plt.legend()
plt.grid(alpha=.3)
plt.show()

plt.figure(figsize=(17,4))
plt.plot(history['accuracy'], label='Training accuracy', alpha=.8, color='#ff7f0e')
plt.plot(history['val_accuracy'], label='Validation accuracy', alpha=.9, color='#5a9aa5')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
plt.title('Accuracy')
plt.legend()
plt.grid(alpha=.3)
plt.show()

plt.figure(figsize=(17,4))
plt.plot(history['lr'], label='Learning Rate', alpha=.8, color='#ff7f0e')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
plt.legend()
plt.grid(alpha=.3)
plt.show()

# %%
# Predict the test set with the RNN
predictions = model.predict(X_val)
predictions.shape
# Out:
# 16/16 [==============================] - 0s 7ms/step
# (486, 12)

# %%
# Compute the confusion matrix
cm = confusion_matrix(np.argmax(y_val, axis=-1), np.argmax(predictions, axis=-1))

# Compute the classification metrics
accuracy = accuracy_score(np.argmax(y_val, axis=-1), np.argmax(predictions, axis=-1))
precision = precision_score(np.argmax(y_val, axis=-1), np.argmax(predictions, axis=-1), average='macro')
recall = recall_score(np.argmax(y_val, axis=-1), np.argmax(predictions, axis=-1), average='macro')
f1 = f1_score(np.argmax(y_val, axis=-1), np.argmax(predictions, axis=-1), average='macro')
print('Accuracy:',accuracy.round(4))
print('Precision:',precision.round(4))
print('Recall:',recall.round(4))
print('F1:',f1.round(4))

# Plot the confusion matrix
plt.figure(figsize=(10,8))
sns.heatmap(cm.T, cmap='Blues', xticklabels=list(label_mapping), yticklabels=list(label_mapping), annot=True)
plt.xlabel('True labels')
plt.ylabel('Predicted labels')
plt.show()
# Out:
# Accuracy: 0.4877
# Precision: 0.5018
# Recall: 0.5789
# F1: 0.4969

# %%
f1s = f1_score(np.argmax(y_val, axis=-1), np.argmax(predictions, axis=-1), average=None)

fig = plt.figure(figsize=(21, 5))
plt.bar(np.arange(12), f1s, width=1, edgecolor="white", tick_label=list(label_mapping))

plt.show()

# %%
#model.save(model_name)
# model = tfk.models.load_model(model_name)
