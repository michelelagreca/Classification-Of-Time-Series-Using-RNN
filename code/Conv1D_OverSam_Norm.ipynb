# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/ANN2DL_HW2_Shared
# Out:
# /content/drive/MyDrive/ANN2DL_HW2_Shared

# %%
import tensorflow as tf
import numpy as np
import os
import random
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.rc('font', size=16) 
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_class_weight
from imblearn.over_sampling import RandomOverSampler, SMOTE, ADASYN
from imblearn.combine import SMOTEENN, SMOTETomek
import warnings
import logging

tfk = tf.keras
tfkl = tf.keras.layers
print(tf.__version__)
# Out:
# 2.9.2

# %%
# Random seed for reproducibility
seed = 42

random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)

# %%
x_file_path = "./original_data/x_train.npy"
y_file_path = "./original_data/y_train.npy"

X = np.load(x_file_path)
y = np.load(y_file_path)

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, random_state=seed)
n_dimensions = X_train.shape[2]
X_train.shape, y_train.shape, X_val.shape, y_val.shape
# Out:
# ((1943, 36, 6), (1943,), (486, 36, 6), (486,))

# %%
label_mapping = {
    "Wish",
    "Another",
    "Comfortably",
    "Money",
    "Breathe",
    "Time",
    "Brain",
    "Echoes",
    "Wearing",
    "Sorrow",
    "Hey",
    "Shine"
}

# %%
def normalize(X_train, axis, norm_type='no_norm'):
  axs = [0,1,2]
  axs.remove(axis)
  axs=tuple(axs)

  means = np.mean(X_train, axis=axs)
  stds = np.std(X_train, axis=axs)
  mins = np.min(X_train, axis=axs)
  maxs = np.max(X_train, axis=axs)

  params = {
      "means": means,
      "stds": stds,
      "mins": mins,
      "maxs": maxs
  }
  
  if norm_type=='standard':
    X_std_train = []
    
    for i in range(X_train.shape[axis]):
      data = np.take(X_train, i, axis=axis)
      data = (data - means[i]) / stds[i]
      X_std_train.append(data)

    X_std_train = tuple(X_std_train)
    X_std_train = np.stack(X_std_train, axis=axis)

    return X_std_train, params


  elif norm_type=='minmax':
    X_norm_train = []
    
    for i in range(X_train.shape[axis]):
      data = np.take(X_train, i, axis=axis)
      data = (data - mins[i]) / (maxs[i] - mins[i])
      X_norm_train.append(data)

    X_norm_train = tuple(X_norm_train)
    X_norm_train = np.stack(X_norm_train, axis=axis)

    return X_norm_train, params

  else:
    return X_train, params

# %%
def normalize_test(X, params, axis, norm_type='no_norm'):
  
  if norm_type=='standard':
    X_std_val = []

    means = params["means"]
    stds = params["stds"]
    mins = params["mins"]
    maxs = params["maxs"]

    for i in range(X.shape[axis]):
      data = np.take(X, i, axis=axis)
      data = (data - means[i]) / stds[i]
      X_std_val.append(data)

    X_std_val = tuple(X_std_val)
    X_std_val = np.stack(X_std_val, axis=axis)

    return X_std_val

  elif norm_type=='minmax':
    X_norm_val = []
    
    for i in range(X.shape[axis]):
      data = np.take(X, i, axis=axis)
      data = (data - mins[i]) / (maxs[i] - min)
      X_norm_val.append(data)

    X_norm_val = tuple(X_norm_val)
    X_norm_val = np.stack(X_norm_val, axis=axis)

    return X_norm_val

  else:
    return X

# %%
axis = 2
n_t = 'standard'

X_train, p = normalize(X_train, axis, norm_type=n_t)
X_val = normalize_test(X_val, p, axis, norm_type=n_t)

# %%
class_weights = compute_class_weight(class_weight='balanced', classes=np.unique(y), y=y)

fig = plt.figure(figsize=(21, 5))
plt.bar(np.arange(12), class_weights, width=1, edgecolor="white", tick_label=list(label_mapping))
plt.show()

# %%
class_weights = dict(zip(np.arange(12), class_weights))
class_weights
# Out:
# {0: 5.953431372549019,
#  1: 1.6456639566395663,
#  2: 0.7496913580246913,
#  3: 0.5312773403324584,
#  4: 3.264784946236559,
#  5: 1.3229847494553377,
#  6: 0.6466986155484558,
#  7: 2.9767156862745097,
#  8: 1.6868055555555554,
#  9: 0.2605105105105105,
#  10: 2.628787878787879,
#  11: 3.968954248366013}

# %%
ros = RandomOverSampler(random_state=seed)
smote = SMOTE(random_state=seed)
adasyn = ADASYN(random_state=seed)
smoteenn = SMOTEENN(random_state=seed)
smote_tomek = SMOTETomek(random_state=seed)

X1 = []

for dim in range(n_dimensions):
  X_dim = X_train[:,:,dim]
  X1.append(X_dim)

X1 = np.concatenate(X1, axis=1)
X_ros, y_ros = smote_tomek.fit_resample(X1, y_train)
X_ros = np.reshape(X_ros, (X_ros.shape[0], 36, 6), order='F')
X_ros.shape, y_ros.shape
# Out:
# ((7466, 36, 6), (7466,))

# %%
#fig = plt.figure(figsize=(21, 5))
plt.bar(np.arange(12), np.argmax(y_ros), width=1, edgecolor="white", tick_label=list(np.arange(12)))
plt.show()

# %%
y_train = y_ros
y_train = tfk.utils.to_categorical(y_train)
y_val = tfk.utils.to_categorical(y_val)
y_train.shape, y_val.shape
# Out:
# ((7466, 12), (486, 12))

# %%
X_train = X_ros
X_train.shape, y_train.shape
# Out:
# ((7466, 36, 6), (7466, 12))

# %%
# Utility function to create folders and callbacks for training
from datetime import datetime

def create_folders_and_callbacks(model_name, experiments_name):

  exps_dir = os.path.join(experiments_name)
  if not os.path.exists(exps_dir):
      os.makedirs(exps_dir)

  now = datetime.now().strftime('%b%d_%H-%M-%S')

  exp_dir = os.path.join(exps_dir, model_name + '_' + str(now))
  if not os.path.exists(exp_dir):
      os.makedirs(exp_dir)
      
  callbacks = []

  # Model checkpoint
  # ----------------
  ckpt_dir = os.path.join(exp_dir, 'ckpts')
  if not os.path.exists(ckpt_dir):
      os.makedirs(ckpt_dir)

  ckpt_callback = tf.keras.callbacks.ModelCheckpoint(filepath=os.path.join(ckpt_dir, 'cp.ckpt'), 
                                                     save_weights_only=True, # True to save only weights
                                                     save_best_only=False) # True to save only the best epoch 
  callbacks.append(ckpt_callback)

  # Visualize Learning on Tensorboard
  # ---------------------------------
  tb_dir = os.path.join(exp_dir, 'tb_logs')
  if not os.path.exists(tb_dir):
      os.makedirs(tb_dir)
      
  # By default shows losses and metrics for both training and validation
  tb_callback = tf.keras.callbacks.TensorBoard(log_dir=tb_dir, 
                                               profile_batch=0,
                                               histogram_freq=1)  # if > 0 (epochs) shows weights histograms
  callbacks.append(tb_callback)

  return callbacks

# %%
def build_classifier(input_shape, classes, model_name, lr=0.001):
    # Build the neural network layer by layer
    input_layer = tfkl.Input(shape=input_shape, name='Input')

    b_lstm = tfkl.Bidirectional(tfkl.LSTM(256, return_sequences=True))(input_layer)
    b_lstm = tfkl.Bidirectional(tfkl.LSTM(256, return_sequences=True))(b_lstm)
    #b_lstm = tfkl.Dropout(0.4, seed=seed)(b_lstm)

    # Feature extractor
    cnn1 = tfkl.Conv1D(128,3,padding='same',activation='relu')(input_layer)
    b1 = tfkl.BatchNormalization()(cnn1)
    cnn2 = tfkl.Conv1D(128,3,padding='same',activation='relu')(cnn1)
    b2 = tfkl.BatchNormalization()(cnn2)
    cnn3 = tfkl.Conv1D(128,3,padding='same',activation='relu')(b2)
    cnn = tfkl.Add()([b1, b2, cnn3])
    cnn = tfkl.MaxPooling1D()(cnn)
    
    cnn1 = tfkl.Conv1D(128,3,padding='same',activation='relu')(input_layer)
    b1 = tfkl.BatchNormalization()(cnn1)
    cnn2 = tfkl.Conv1D(128,3,padding='same',activation='relu')(cnn1)
    b2 = tfkl.BatchNormalization()(cnn2)
    cnn3 = tfkl.Conv1D(128,3,padding='same',activation='relu')(b2)
    cnn = tfkl.Add()([b1, b2, cnn3])
    cnn = tfkl.MaxPooling1D()(cnn)

    cnn1 = tfkl.Conv1D(128,3,padding='same',activation='relu')(input_layer)
    b1 = tfkl.BatchNormalization()(cnn1)
    cnn2 = tfkl.Conv1D(128,3,padding='same',activation='relu')(cnn1)
    b2 = tfkl.BatchNormalization()(cnn2)
    cnn3 = tfkl.Conv1D(128,3,padding='same',activation='relu')(b2)
    cnn = tfkl.Add()([b1, b2, cnn3])
    cnn = tfkl.MaxPooling1D()(cnn)

    gap = tfkl.GlobalAveragePooling1D()(cnn)
    #gap = tfkl.Dropout(0.4, seed=seed)(gap)

    # Classifier
    classifier = tfkl.Dense(256, activation='relu')(gap)
    #classifier = tfkl.Dropout(0.4, seed=seed)(classifier)
    
    output_layer = tfkl.Dense(12, activation='softmax')(classifier)

    # Connect input and output through the Model class
    model = tfk.Model(inputs=input_layer, outputs=output_layer, name=model_name)

    # Compile the model
    model.compile(loss=tfk.losses.CategoricalCrossentropy(), optimizer=tfk.optimizers.Adam(lr), metrics='accuracy')

    # Return the model
    return model

# %%
model_name = "Conv1D"
experiments_name = "Oversampling_weighted_loss_normalization"

input_shape = X_train.shape[1:]
classes = y_train.shape[-1]
batch_size = 128
epochs = 200

patience1 = 25
patience_plateau = 5
min_lr = 1e-5
lr_factor = 0.5

# %%
model = build_classifier(input_shape, classes, model_name)
model.summary()
# Out:
# Model: "Conv1D"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  Input (InputLayer)             [(None, 36, 6)]      0           []
#
#  conv1d_6 (Conv1D)              (None, 36, 128)      2432        ['Input[0][0]']
#
#  conv1d_7 (Conv1D)              (None, 36, 128)      49280       ['conv1d_6[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 36, 128)     512         ['conv1d_7[0][0]']
#  rmalization)
#
#  batch_normalization_4 (BatchNo  (None, 36, 128)     512         ['conv1d_6[0][0]']
#  rmalization)
#
#  conv1d_8 (Conv1D)              (None, 36, 128)      49280       ['batch_normalization_5[0][0]']
#
#  add_2 (Add)                    (None, 36, 128)      0           ['batch_normalization_4[0][0]',
#                                                                   'batch_normalization_5[0][0]',
#                                                                   'conv1d_8[0][0]']
#
#  max_pooling1d_2 (MaxPooling1D)  (None, 18, 128)     0           ['add_2[0][0]']
#
#  global_average_pooling1d (Glob  (None, 128)         0           ['max_pooling1d_2[0][0]']
#  alAveragePooling1D)
#
#  dense (Dense)                  (None, 256)          33024       ['global_average_pooling1d[0][0]'
#                                                                  ]
#
#  dense_1 (Dense)                (None, 12)           3084        ['dense[0][0]']
#
# ==================================================================================================
# Total params: 138,124
# Trainable params: 137,612
# Non-trainable params: 512
# __________________________________________________________________________________________________

# %%
# %cd ./andrea/Conv1D
# Out:
# /content/drive/MyDrive/ANN2DL_HW2_Shared/andrea/Conv1D

# %%
# Create folders and callbacks and fit
cbs = create_folders_and_callbacks(model_name, experiments_name)
cbs.append([tfk.callbacks.EarlyStopping(monitor='val_accuracy', mode='max', patience=patience1, restore_best_weights=True),
        tfk.callbacks.ReduceLROnPlateau(monitor='val_accuracy', mode='max', patience=patience_plateau, factor=lr_factor, min_lr=min_lr)])

# Train the model
history = model.fit(
    x = X_train,
    y = y_train,
    batch_size = batch_size,
    epochs = epochs,
    validation_data=(X_val, y_val),
    callbacks = cbs,
    shuffle = True
).history
# Out:
# Epoch 1/200
# 59/59 [==============================] - 10s 18ms/step - loss: 1.9839 - accuracy: 0.3328 - val_loss: 2.3463 - val_accuracy: 0.2202 - lr: 0.0010
# Epoch 2/200
# 59/59 [==============================] - 1s 10ms/step - loss: 1.4255 - accuracy: 0.4960 - val_loss: 2.0468 - val_accuracy: 0.4671 - lr: 0.0010
# Epoch 3/200
# 59/59 [==============================] - 1s 9ms/step - loss: 1.1858 - accuracy: 0.5884 - val_loss: 1.7909 - val_accuracy: 0.5206 - lr: 0.0010
# Epoch 4/200
# 59/59 [==============================] - 1s 9ms/step - loss: 0.9972 - accuracy: 0.6559 - val_loss: 1.6367 - val_accuracy: 0.4897 - lr: 0.0010
# Epoch 5/200
# 59/59 [==============================] - 1s 9ms/step - loss: 0.8868 - accuracy: 0.6915 - val_loss: 1.4739 - val_accuracy: 0.5103 - lr: 0.0010
# Epoch 6/200
# 59/59 [==============================] - 1s 9ms/step - loss: 0.7949 - accuracy: 0.7171 - val_loss: 1.4130 - val_accuracy: 0.4733 - lr: 0.0010
# Epoch 7/200
# 59/59 [==============================] - 1s 9ms/step - loss: 0.7258 - accuracy: 0.7448 - val_loss: 1.3333 - val_accuracy: 0.5453 - lr: 0.0010
# Epoch 8/200
# 59/59 [==============================] - 1s 9ms/step - loss: 0.6842 - accuracy: 0.7562 - val_loss: 1.2484 - val_accuracy: 0.5062 - lr: 0.0010
# Epoch 9/200
# 59/59 [==============================] - 1s 9ms/step - loss: 0.6225 - accuracy: 0.7787 - val_loss: 1.3259 - val_accuracy: 0.4918 - lr: 0.0010
# Epoch 10/200
# 59/59 [==============================] - 1s 10ms/step - loss: 0.5561 - accuracy: 0.8086 - val_loss: 1.1981 - val_accuracy: 0.5658 - lr: 0.0010
# Epoch 11/200
# 59/59 [==============================] - 1s 9ms/step - loss: 0.5283 - accuracy: 0.8142 - val_loss: 1.2105 - val_accuracy: 0.5617 - lr: 0.0010
# Epoch 12/200
# 59/59 [==============================] - 1s 9ms/step - loss: 0.5415 - accuracy: 0.8115 - val_loss: 1.4127 - val_accuracy: 0.5309 - lr: 0.0010
# Epoch 13/200
# 59/59 [==============================] - 1s 9ms/step - loss: 0.4591 - accuracy: 0.8429 - val_loss: 1.2847 - val_accuracy: 0.5617 - lr: 0.0010
# Epoch 14/200
# 59/59 [==============================] - 1s 10ms/step - loss: 0.4202 - accuracy: 0.8563 - val_loss: 1.2963 - val_accuracy: 0.5947 - lr: 0.0010
# Epoch 15/200
# 59/59 [==============================] - 1s 9ms/step - loss: 0.4213 - accuracy: 0.8519 - val_loss: 1.3591 - val_accuracy: 0.5700 - lr: 0.0010
# Epoch 16/200
# 59/59 [==============================] - 1s 9ms/step - loss: 0.3634 - accuracy: 0.8786 - val_loss: 1.6483 - val_accuracy: 0.5741 - lr: 0.0010
# Epoch 17/200
# 59/59 [==============================] - 1s 10ms/step - loss: 0.3708 - accuracy: 0.8738 - val_loss: 1.4353 - val_accuracy: 0.5638 - lr: 0.0010
# Epoch 18/200
# 59/59 [==============================] - 1s 9ms/step - loss: 0.3319 - accuracy: 0.8926 - val_loss: 1.6588 - val_accuracy: 0.5556 - lr: 0.0010
# Epoch 19/200
# 59/59 [==============================] - 1s 9ms/step - loss: 0.3019 - accuracy: 0.8962 - val_loss: 1.4611 - val_accuracy: 0.5597 - lr: 0.0010
# Epoch 20/200
# 59/59 [==============================] - 1s 9ms/step - loss: 0.2466 - accuracy: 0.9218 - val_loss: 1.3357 - val_accuracy: 0.6276 - lr: 5.0000e-04
# Epoch 21/200
# 59/59 [==============================] - 1s 9ms/step - loss: 0.2258 - accuracy: 0.9289 - val_loss: 1.4836 - val_accuracy: 0.5700 - lr: 5.0000e-04
# Epoch 22/200
# 59/59 [==============================] - 1s 9ms/step - loss: 0.2137 - accuracy: 0.9297 - val_loss: 1.3656 - val_accuracy: 0.6667 - lr: 5.0000e-04
# Epoch 23/200
# 59/59 [==============================] - 1s 9ms/step - loss: 0.2216 - accuracy: 0.9274 - val_loss: 1.3675 - val_accuracy: 0.6934 - lr: 5.0000e-04
# Epoch 24/200
# 59/59 [==============================] - 1s 9ms/step - loss: 0.1971 - accuracy: 0.9373 - val_loss: 1.3533 - val_accuracy: 0.6749 - lr: 5.0000e-04
# Epoch 25/200
# 59/59 [==============================] - 1s 9ms/step - loss: 0.1796 - accuracy: 0.9466 - val_loss: 1.5002 - val_accuracy: 0.6235 - lr: 5.0000e-04
# Epoch 26/200
# 59/59 [==============================] - 1s 10ms/step - loss: 0.1765 - accuracy: 0.9450 - val_loss: 1.4051 - val_accuracy: 0.6564 - lr: 5.0000e-04
# Epoch 27/200
# 59/59 [==============================] - 1s 9ms/step - loss: 0.1610 - accuracy: 0.9504 - val_loss: 1.5125 - val_accuracy: 0.6399 - lr: 5.0000e-04
# Epoch 28/200
# 59/59 [==============================] - 1s 10ms/step - loss: 0.1791 - accuracy: 0.9415 - val_loss: 1.4819 - val_accuracy: 0.6235 - lr: 5.0000e-04
# Epoch 29/200
# 59/59 [==============================] - 1s 10ms/step - loss: 0.1450 - accuracy: 0.9604 - val_loss: 1.4336 - val_accuracy: 0.6687 - lr: 2.5000e-04
# Epoch 30/200
# 59/59 [==============================] - 1s 9ms/step - loss: 0.1358 - accuracy: 0.9608 - val_loss: 1.4213 - val_accuracy: 0.6770 - lr: 2.5000e-04
# Epoch 31/200
# 59/59 [==============================] - 1s 10ms/step - loss: 0.1252 - accuracy: 0.9665 - val_loss: 1.4555 - val_accuracy: 0.6811 - lr: 2.5000e-04
# Epoch 32/200
# 59/59 [==============================] - 1s 10ms/step - loss: 0.1303 - accuracy: 0.9616 - val_loss: 1.5862 - val_accuracy: 0.6173 - lr: 2.5000e-04
# Epoch 33/200
# 59/59 [==============================] - 1s 9ms/step - loss: 0.1270 - accuracy: 0.9644 - val_loss: 1.4837 - val_accuracy: 0.6811 - lr: 2.5000e-04
# Epoch 34/200
# 59/59 [==============================] - 1s 9ms/step - loss: 0.1151 - accuracy: 0.9688 - val_loss: 1.4710 - val_accuracy: 0.6728 - lr: 1.2500e-04
# Epoch 35/200
# 59/59 [==============================] - 1s 9ms/step - loss: 0.1110 - accuracy: 0.9715 - val_loss: 1.5414 - val_accuracy: 0.6399 - lr: 1.2500e-04
# Epoch 36/200
# 59/59 [==============================] - 1s 9ms/step - loss: 0.1084 - accuracy: 0.9728 - val_loss: 1.5266 - val_accuracy: 0.6831 - lr: 1.2500e-04
# Epoch 37/200
# 59/59 [==============================] - 1s 9ms/step - loss: 0.1087 - accuracy: 0.9725 - val_loss: 1.5040 - val_accuracy: 0.6502 - lr: 1.2500e-04
# Epoch 38/200
# 59/59 [==============================] - 1s 10ms/step - loss: 0.1083 - accuracy: 0.9731 - val_loss: 1.5840 - val_accuracy: 0.6358 - lr: 1.2500e-04
# Epoch 39/200
# 59/59 [==============================] - 1s 9ms/step - loss: 0.1010 - accuracy: 0.9747 - val_loss: 1.5042 - val_accuracy: 0.6667 - lr: 6.2500e-05
# Epoch 40/200
# 59/59 [==============================] - 1s 9ms/step - loss: 0.1000 - accuracy: 0.9758 - val_loss: 1.5180 - val_accuracy: 0.6543 - lr: 6.2500e-05
# Epoch 41/200
# 59/59 [==============================] - 1s 10ms/step - loss: 0.0996 - accuracy: 0.9759 - val_loss: 1.5085 - val_accuracy: 0.6852 - lr: 6.2500e-05
# Epoch 42/200
# 59/59 [==============================] - 1s 9ms/step - loss: 0.0988 - accuracy: 0.9763 - val_loss: 1.5191 - val_accuracy: 0.6728 - lr: 6.2500e-05
# Epoch 43/200
# 59/59 [==============================] - 1s 9ms/step - loss: 0.0983 - accuracy: 0.9756 - val_loss: 1.5340 - val_accuracy: 0.6667 - lr: 6.2500e-05
# Epoch 44/200
# 59/59 [==============================] - 1s 14ms/step - loss: 0.0946 - accuracy: 0.9766 - val_loss: 1.5213 - val_accuracy: 0.6728 - lr: 3.1250e-05
# Epoch 45/200
# 59/59 [==============================] - 1s 15ms/step - loss: 0.0960 - accuracy: 0.9763 - val_loss: 1.5339 - val_accuracy: 0.6543 - lr: 3.1250e-05
# Epoch 46/200
# 59/59 [==============================] - 1s 9ms/step - loss: 0.0961 - accuracy: 0.9772 - val_loss: 1.5346 - val_accuracy: 0.6626 - lr: 3.1250e-05
# Epoch 47/200
# 59/59 [==============================] - 1s 14ms/step - loss: 0.0939 - accuracy: 0.9772 - val_loss: 1.5381 - val_accuracy: 0.6646 - lr: 3.1250e-05
# Epoch 48/200
# 59/59 [==============================] - 1s 10ms/step - loss: 0.0936 - accuracy: 0.9778 - val_loss: 1.5500 - val_accuracy: 0.6523 - lr: 3.1250e-05

# %%
best_epoch = np.argmax(history['val_accuracy'])
plt.figure(figsize=(17,4))
plt.plot(history['loss'], label='Training loss', alpha=.8, color='#ff7f0e')
plt.plot(history['val_loss'], label='Validation loss', alpha=.9, color='#5a9aa5')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
plt.title('Categorical Crossentropy')
plt.legend()
plt.grid(alpha=.3)
plt.show()

plt.figure(figsize=(17,4))
plt.plot(history['accuracy'], label='Training accuracy', alpha=.8, color='#ff7f0e')
plt.plot(history['val_accuracy'], label='Validation accuracy', alpha=.9, color='#5a9aa5')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
plt.title('Accuracy')
plt.legend()
plt.grid(alpha=.3)
plt.show()

plt.figure(figsize=(17,4))
plt.plot(history['lr'], label='Learning Rate', alpha=.8, color='#ff7f0e')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
plt.legend()
plt.grid(alpha=.3)
plt.show()

# %%
# Predict the test set with the RNN
predictions = model.predict(X_val)
predictions.shape
# Out:
# 16/16 [==============================] - 0s 5ms/step
# (486, 12)

# %%
# Compute the confusion matrix
cm = confusion_matrix(np.argmax(y_val, axis=-1), np.argmax(predictions, axis=-1))

# Compute the classification metrics
accuracy = accuracy_score(np.argmax(y_val, axis=-1), np.argmax(predictions, axis=-1))
precision = precision_score(np.argmax(y_val, axis=-1), np.argmax(predictions, axis=-1), average='macro')
recall = recall_score(np.argmax(y_val, axis=-1), np.argmax(predictions, axis=-1), average='macro')
f1 = f1_score(np.argmax(y_val, axis=-1), np.argmax(predictions, axis=-1), average='macro')
print('Accuracy:',accuracy.round(4))
print('Precision:',precision.round(4))
print('Recall:',recall.round(4))
print('F1:',f1.round(4))

# Plot the confusion matrix
plt.figure(figsize=(10,8))
sns.heatmap(cm.T, cmap='Blues', xticklabels=list(label_mapping), yticklabels=list(label_mapping), annot=True)
plt.xlabel('True labels')
plt.ylabel('Predicted labels')
plt.show()
# Out:
# Accuracy: 0.6934
# Precision: 0.6186
# Recall: 0.608
# F1: 0.5937

# %%
f1s = f1_score(np.argmax(y_val, axis=-1), np.argmax(predictions, axis=-1), average=None)

fig = plt.figure(figsize=(21, 5))
plt.bar(np.arange(12), f1s, width=1, edgecolor="white", tick_label=list(label_mapping))

plt.show()

# %%
model.save(model_name)
# model = tfk.models.load_model(model_name)
# Out:
# WARNING:absl:Function `_wrapped_model` contains input name(s) Input with unsupported characters which will be renamed to input in the SavedModel.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 3 of 3). These functions will not be directly callable after loading.
