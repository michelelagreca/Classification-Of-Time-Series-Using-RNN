# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/ANN2DL_HW2_Shared
# Out:
# /content/drive/MyDrive/ANN2DL_HW2_Shared

# %%
import tensorflow as tf
import numpy as np
import os
import random
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.rc('font', size=16) 
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.utils import resample
from sklearn.utils.class_weight import compute_class_weight
from imblearn.over_sampling import RandomOverSampler, SMOTE, ADASYN
from imblearn.combine import SMOTEENN, SMOTETomek
import shutil
import warnings
import logging

tfk = tf.keras
tfkl = tf.keras.layers
print(tf.__version__)
# Out:
# 2.9.2

# %%
# Random seed for reproducibility
seed = 42

random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)

# %%
normalization = 'standard'
axis = 2
class_weighting = False
oversampling = False

# %% [markdown]
# # Load and preprocess data

# %%
x_file_path = "./original_data/x_train.npy"
y_file_path = "./original_data/y_train.npy"

X = np.load(x_file_path)
y = np.load(y_file_path)

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.1, random_state=seed)
n_dimensions = X_train.shape[2]
X_train.shape, y_train.shape, X_val.shape, y_val.shape
# Out:
# ((2186, 36, 6), (2186,), (243, 36, 6), (243,))

# %%
label_mapping = {
    "Wish",
    "Another",
    "Comfortably",
    "Money",
    "Breathe",
    "Time",
    "Brain",
    "Echoes",
    "Wearing",
    "Sorrow",
    "Hey",
    "Shine"
}

# %% [markdown]
# ## Normalization

# %%
def normalize(X_train, axis, norm_type='no_norm'):
  axs = [0,1,2]
  axs.remove(axis)
  axs=tuple(axs)

  means = np.mean(X_train, axis=axs)
  stds = np.std(X_train, axis=axs)
  mins = np.min(X_train, axis=axs)
  maxs = np.max(X_train, axis=axs)

  params = {
      "means": means,
      "stds": stds,
      "mins": mins,
      "maxs": maxs
  }
  
  if norm_type=='standard':
    X_std_train = []
    
    for i in range(X_train.shape[axis]):
      data = np.take(X_train, i, axis=axis)
      data = (data - means[i]) / stds[i]
      X_std_train.append(data)

    X_std_train = tuple(X_std_train)
    X_std_train = np.stack(X_std_train, axis=axis)

    return X_std_train, params


  elif norm_type=='minmax':
    X_norm_train = []
    
    for i in range(X_train.shape[axis]):
      data = np.take(X_train, i, axis=axis)
      data = (data - mins[i]) / (maxs[i] - mins[i])
      X_norm_train.append(data)

    X_norm_train = tuple(X_norm_train)
    X_norm_train = np.stack(X_norm_train, axis=axis)

    return X_norm_train, params

  else:
    return X_train, params

# %%
def normalize_test(X, params, axis, norm_type='no_norm'):
  
  if norm_type=='standard':
    X_std_val = []

    means = params["means"]
    stds = params["stds"]
    mins = params["mins"]
    maxs = params["maxs"]

    for i in range(X.shape[axis]):
      data = np.take(X, i, axis=axis)
      data = (data - means[i]) / stds[i]
      X_std_val.append(data)

    X_std_val = tuple(X_std_val)
    X_std_val = np.stack(X_std_val, axis=axis)

    return X_std_val

  elif norm_type=='minmax':
    X_norm_val = []
    
    for i in range(X.shape[axis]):
      data = np.take(X, i, axis=axis)
      data = (data - mins[i]) / (maxs[i] - min)
      X_norm_val.append(data)

    X_norm_val = tuple(X_norm_val)
    X_norm_val = np.stack(X_norm_val, axis=axis)

    return X_norm_val

  else:
    return X

# %%
X_train, p = normalize(X_train, axis, norm_type=normalization)
X_val = normalize_test(X_val, p, axis, norm_type=normalization)

# %% [markdown]
# ## Comput class weights

# %%
if class_weighting:
  class_weights = compute_class_weight(class_weight='balanced', classes=np.unique(y), y=y)

  fig = plt.figure(figsize=(21, 5))
  plt.bar(np.arange(12), class_weights, width=1, edgecolor="white", tick_label=list(label_mapping))
  plt.show()

# %%
if class_weighting:
  class_weights = dict(zip(np.arange(12), class_weights))
  class_weights

# %% [markdown]
# ## Random oversampling and undersampling

# %%
if oversampling:
  ros = RandomOverSampler(random_state=seed)
  smote = SMOTE(random_state=seed)
  adasyn = ADASYN(random_state=seed)
  smoteenn = SMOTEENN(random_state=seed)
  smote_tomek = SMOTETomek(random_state=seed)

  X1 = []

  for dim in range(n_dimensions):
    X_dim = X_train[:,:,dim]
    X1.append(X_dim)

  X1 = np.concatenate(X1, axis=1)
  X_ros, y_ros = adasyn.fit_resample(X1, y_train)
  X_ros = np.reshape(X_ros, (X_ros.shape[0], 36, 6), order='F')
  X_train, y_train = X_ros, y_ros

# %%
if oversampling:
  plt.bar(np.arange(12), np.argmax(y_ros), width=1, edgecolor="white", tick_label=list(np.arange(12)))
  plt.show()

# %% [markdown]
# # to categorical data

# %%
y_train = tfk.utils.to_categorical(y_train)
y_val = tfk.utils.to_categorical(y_val)
y_train.shape, y_val.shape
# Out:
# ((2186, 12), (243, 12))

# %%
X_train.shape, y_train.shape
# Out:
# ((2186, 36, 6), (2186, 12))

# %% [markdown]
# # Utility function and classes definitions

# %%
# Utility function to create folders and callbacks for training
from datetime import datetime

def create_folders_and_callbacks(model_name, experiments_name):

  exps_dir = os.path.join(experiments_name)
  if not os.path.exists(exps_dir):
      os.makedirs(exps_dir)

  now = datetime.now().strftime('%b%d_%H-%M-%S')

  exp_dir = os.path.join(exps_dir, model_name + '_' + str(now))
  if not os.path.exists(exp_dir):
      os.makedirs(exp_dir)
      
  callbacks = []

  # Model checkpoint
  # ----------------
  ckpt_dir = os.path.join(exp_dir, 'ckpts')
  if not os.path.exists(ckpt_dir):
      os.makedirs(ckpt_dir)

  ckpt_callback = tf.keras.callbacks.ModelCheckpoint(filepath=os.path.join(ckpt_dir, 'cp.ckpt'), 
                                                     save_weights_only=True, # True to save only weights
                                                     save_best_only=False) # True to save only the best epoch 
  callbacks.append(ckpt_callback)

  # Visualize Learning on Tensorboard
  # ---------------------------------
  tb_dir = os.path.join(exp_dir, 'tb_logs')
  if not os.path.exists(tb_dir):
      os.makedirs(tb_dir)
      
  # By default shows losses and metrics for both training and validation
  tb_callback = tf.keras.callbacks.TensorBoard(log_dir=tb_dir, 
                                               profile_batch=0,
                                               histogram_freq=1)  # if > 0 (epochs) shows weights histograms
  callbacks.append(tb_callback)

  return callbacks

# %% [markdown]
# # Model building function

# %%
def build_classifier(input_shape, classes, model_name, lr=0.001):
    # Build the neural network layer by layer
    input_layer = tfkl.Input(shape=input_shape, name='Input')

    # Feature extractor
    cnn1 = tfkl.Conv1D(256,3,padding='same',activation='relu')(input_layer)
    cnn2 = tfkl.Conv1D(256,3,padding='same',activation='relu')(cnn1)
    cnn = tfkl.Add()([cnn1, cnn2])
    cnn = tfkl.MaxPooling1D()(cnn)
    
    cnn1 = tfkl.Conv1D(256,3,padding='same',activation='relu')(cnn)
    cnn2 = tfkl.Conv1D(256,3,padding='same',activation='relu')(cnn1)
    cnn = tfkl.Add()([cnn1, cnn2])
    cnn = tfkl.MaxPooling1D()(cnn)

    drop = tfkl.Dropout(0.4)(cnn)

    cnn1 = tfkl.Conv1D(256,3,padding='same',activation='relu')(drop)
    cnn2 = tfkl.Conv1D(256,3,padding='same',activation='relu')(cnn1)
    cnn = tfkl.Add()([cnn1, cnn2])
    cnn = tfkl.MaxPooling1D()(cnn)

    cnn1 = tfkl.Conv1D(256,3,padding='same',activation='relu')(cnn)
    cnn2 = tfkl.Conv1D(256,3,padding='same',activation='relu')(cnn1)
    cnn = tfkl.Add()([cnn1, cnn2])
    cnn = tfkl.MaxPooling1D()(cnn)

    drop = tfkl.Dropout(0.4)(cnn)

    gap = tfkl.GlobalAveragePooling1D()(drop)
    #gap = tfkl.Dropout(0.4, seed=seed)(gap)

    # Classifier
    classifier = tfkl.Dense(256, activation='relu', kernel_regularizer=tfk.regularizers.L1L2(l1=1e-4, l2=1e-3))(gap)
    #classifier = tfkl.Dropout(0.4, seed=seed)(classifier)

    drop = tfkl.Dropout(0.4)(classifier)
    
    output_layer = tfkl.Dense(12, activation='softmax')(drop)

    # Connect input and output through the Model class
    model = tfk.Model(inputs=input_layer, outputs=output_layer, name=model_name)

    # Compile the model
    model.compile(loss=tfk.losses.CategoricalCrossentropy(), optimizer=tfk.optimizers.Adam(lr), metrics='accuracy')

    # Return the model
    return model

# %% [markdown]
# # Parameters for training

# %%
model_name = "Conv1D_bagging_without_oversampling"
experiments_name = "Oversampling_weighted_loss_normalization"

n_splits = 20

input_shape = X_train.shape[1:]
classes = y_train.shape[-1]
batch_size = 128
epochs = 200

patience1 = 20
patience_plateau = 5
min_lr = 1e-5
lr_factor = 0.5

# %% [markdown]
# # Build the model

# %%
model = build_classifier(input_shape, classes, model_name)
model.summary()
# Out:
# Model: "Conv1D_bagging_without_oversampling"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  Input (InputLayer)             [(None, 36, 6)]      0           []
#
#  conv1d_352 (Conv1D)            (None, 36, 256)      4864        ['Input[0][0]']
#
#  conv1d_353 (Conv1D)            (None, 36, 256)      196864      ['conv1d_352[0][0]']
#
#  add_176 (Add)                  (None, 36, 256)      0           ['conv1d_352[0][0]',
#                                                                   'conv1d_353[0][0]']
#
#  max_pooling1d_176 (MaxPooling1  (None, 18, 256)     0           ['add_176[0][0]']
#  D)
#
#  conv1d_354 (Conv1D)            (None, 18, 256)      196864      ['max_pooling1d_176[0][0]']
#
#  conv1d_355 (Conv1D)            (None, 18, 256)      196864      ['conv1d_354[0][0]']
#
#  add_177 (Add)                  (None, 18, 256)      0           ['conv1d_354[0][0]',
#                                                                   'conv1d_355[0][0]']
#
#  max_pooling1d_177 (MaxPooling1  (None, 9, 256)      0           ['add_177[0][0]']
#  D)
#
#  dropout_131 (Dropout)          (None, 9, 256)       0           ['max_pooling1d_177[0][0]']
#
#  conv1d_356 (Conv1D)            (None, 9, 256)       196864      ['dropout_131[0][0]']
#
#  conv1d_357 (Conv1D)            (None, 9, 256)       196864      ['conv1d_356[0][0]']
#
#  add_178 (Add)                  (None, 9, 256)       0           ['conv1d_356[0][0]',
#                                                                   'conv1d_357[0][0]']
#
#  max_pooling1d_178 (MaxPooling1  (None, 4, 256)      0           ['add_178[0][0]']
#  D)
#
#  conv1d_358 (Conv1D)            (None, 4, 256)       196864      ['max_pooling1d_178[0][0]']
#
#  conv1d_359 (Conv1D)            (None, 4, 256)       196864      ['conv1d_358[0][0]']
#
#  add_179 (Add)                  (None, 4, 256)       0           ['conv1d_358[0][0]',
#                                                                   'conv1d_359[0][0]']
#
#  max_pooling1d_179 (MaxPooling1  (None, 2, 256)      0           ['add_179[0][0]']
#  D)
#
#  dropout_132 (Dropout)          (None, 2, 256)       0           ['max_pooling1d_179[0][0]']
#
#  global_average_pooling1d_44 (G  (None, 256)         0           ['dropout_132[0][0]']
#  lobalAveragePooling1D)
#
#  dense_86 (Dense)               (None, 256)          65792       ['global_average_pooling1d_44[0][
#                                                                  0]']
#
#  dropout_133 (Dropout)          (None, 256)          0           ['dense_86[0][0]']
#
#  dense_87 (Dense)               (None, 12)           3084        ['dropout_133[0][0]']
#
# ==================================================================================================
# Total params: 1,451,788
# Trainable params: 1,451,788
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# # Bagging class definition

# %%
class BaggingModel(tfk.Model):
  def __init__(self, n_splits, inp, classes, model_name):
    super().__init__()
    self.n_splits = n_splits
    self.inp = inp
    self.classes = classes
    self.model_name = model_name
    self.models = []
    for i in range(self.n_splits):
      name = model_name + str(i)
      self.models.append(build_classifier(self.inp, self.classes, name))

  def fit(self,
    x=None,
    y=None,
    batch_size=None,
    epochs=1,
    verbose='auto',
    callbacks=None,
    validation_split=0.0,
    validation_data=None,
    shuffle=True,
    class_weight=None,
    sample_weight=None,
    initial_epoch=0,
    steps_per_epoch=None,
    validation_steps=None,
    validation_batch_size=None,
    validation_freq=1,
    max_queue_size=10,
    workers=1,
    use_multiprocessing=False):

    cbs = [tfk.callbacks.EarlyStopping(monitor='val_accuracy', mode='max', patience=patience1, restore_best_weights=False),
        tfk.callbacks.ReduceLROnPlateau(monitor='val_accuracy', mode='max', patience=patience_plateau, factor=lr_factor, min_lr=min_lr)]

    for i, model in enumerate(self.models):  
      # multiple train-test splits
      scores = []
      n_samples = x.shape[0]

      # select indexes
      ix = [i for i in range(n_samples)]
      train_ix = resample(ix, replace=True, n_samples=n_samples)
      test_ix = [x for x in ix if x not in train_ix]

      # select data
      X_train, y_train = tf.gather(x, indices=train_ix), y[train_ix]
      X_test, y_test = tf.gather(x, indices=test_ix), y[test_ix]

      # train model
      print("Training of model ", str(i))
      history = model.fit(
        x = X_train,
        y = y_train,
        batch_size = batch_size,
        epochs = epochs,
        validation_data=(X_test, y_test),
        callbacks = cbs,
        shuffle = True
      ).history
      print()

      score = model.evaluate(X_test, y_test)
      scores.append(score)
    
    print("Validation scores for each model:")

    for i, score in enumerate(scores):
      print("Score of model ", str(i))
      print(score)
      print()
        


  def predict(self, x):
    # make predictions
    yhats = [model.predict(x) for model in self.models]
    
    yhats = np.array(yhats)
   
    # sum across ensemble members
    summed = np.sum(yhats, axis=0)

    # argmax across classes
    result = np.argmax(summed, axis=1)

    result = tfk.utils.to_categorical(result)
    
    # return the result
    return result
    pass

  def save(self,
      filepath,
      overwrite=True,
      include_optimizer=True,
      save_format=None,
      signatures=None,
      options=None,
      save_traces=True
  ):

    parent_dir = filepath
    if os.path.exists(parent_dir):
            shutil.rmtree(parent_dir)
    os.mkdir(parent_dir)

    for i, model in enumerate(self.models):
      directory = self.model_name + str(i)
      path = os.path.join(parent_dir, directory)
      if os.path.exists(path):
          shutil.rmtree(path)
      os.mkdir(path)
      model.save(path)

  def load(self, filepath):
    parent_dir = filepath
    for i in range(self.n_splits):
      directory = self.model_name + str(i)
      path = os.path.join(parent_dir, directory)
      if os.path.exists(path):
        self.models[i] = tfk.models.load_model(path)

# %% [markdown]
# # Training

# %%
# %cd ./andrea/Conv1D
# Out:
# /content/drive/MyDrive/ANN2DL_HW2_Shared/andrea/Conv1D

# %%
model = BaggingModel(n_splits, input_shape, classes, model_name)

# %%
model.fit(x = X_train,
      y = y_train,
      batch_size = batch_size,
      epochs = epochs)
# Out:
# Training of model  0
# Epoch 1/200
# 18/18 [==============================] - 2s 39ms/step - loss: 2.9229 - accuracy: 0.2731 - val_loss: 2.6441 - val_accuracy: 0.3176 - lr: 0.0010
# Epoch 2/200
# 18/18 [==============================] - 0s 16ms/step - loss: 2.4868 - accuracy: 0.3550 - val_loss: 2.4700 - val_accuracy: 0.3527 - lr: 0.0010
# Epoch 3/200
# 18/18 [==============================] - 0s 15ms/step - loss: 2.3884 - accuracy: 0.3824 - val_loss: 2.3826 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 4/200
# 18/18 [==============================] - 0s 14ms/step - loss: 2.2588 - accuracy: 0.3994 - val_loss: 2.2421 - val_accuracy: 0.3867 - lr: 0.0010
# Epoch 5/200
# 18/18 [==============================] - 0s 14ms/step - loss: 2.1456 - accuracy: 0.3989 - val_loss: 2.1535 - val_accuracy: 0.4000 - lr: 0.0010
# Epoch 6/200
# 18/18 [==============================] - 0s 15ms/step - loss: 2.0436 - accuracy: 0.4350 - val_loss: 2.2618 - val_accuracy: 0.3830 - lr: 0.0010
# Epoch 7/200
# 18/18 [==============================] - 0s 17ms/step - loss: 2.0400 - accuracy: 0.4460 - val_loss: 2.0838 - val_accuracy: 0.4073 - lr: 0.0010
# Epoch 8/200
# 18/18 [==============================] - 0s 14ms/step - loss: 1.9499 - accuracy: 0.4648 - val_loss: 1.9513 - val_accuracy: 0.4376 - lr: 0.0010
# Epoch 9/200
# 18/18 [==============================] - 0s 14ms/step - loss: 1.7882 - accuracy: 0.4973 - val_loss: 1.8451 - val_accuracy: 0.4764 - lr: 0.0010
# Epoch 10/200
# 18/18 [==============================] - 0s 16ms/step - loss: 1.7959 - accuracy: 0.5087 - val_loss: 1.8940 - val_accuracy: 0.4667 - lr: 0.0010
# Epoch 11/200
# 18/18 [==============================] - 0s 14ms/step - loss: 1.6329 - accuracy: 0.5366 - val_loss: 1.7642 - val_accuracy: 0.5091 - lr: 0.0010
# Epoch 12/200
# 18/18 [==============================] - 0s 16ms/step - loss: 1.4906 - accuracy: 0.5883 - val_loss: 1.7309 - val_accuracy: 0.5467 - lr: 0.0010
# Epoch 13/200
# 18/18 [==============================] - 0s 15ms/step - loss: 1.4313 - accuracy: 0.6002 - val_loss: 1.7441 - val_accuracy: 0.5248 - lr: 0.0010
# Epoch 14/200
# 18/18 [==============================] - 0s 15ms/step - loss: 1.3943 - accuracy: 0.6112 - val_loss: 1.6240 - val_accuracy: 0.5782 - lr: 0.0010
# Epoch 15/200
# 18/18 [==============================] - 0s 16ms/step - loss: 1.3319 - accuracy: 0.6354 - val_loss: 1.7002 - val_accuracy: 0.5467 - lr: 0.0010
# Epoch 16/200
# 18/18 [==============================] - 0s 15ms/step - loss: 1.3151 - accuracy: 0.6349 - val_loss: 1.6275 - val_accuracy: 0.5576 - lr: 0.0010
# Epoch 17/200
# 18/18 [==============================] - 0s 15ms/step - loss: 1.2901 - accuracy: 0.6253 - val_loss: 1.6145 - val_accuracy: 0.5733 - lr: 0.0010
# Epoch 18/200
# 18/18 [==============================] - 0s 14ms/step - loss: 1
200
# 18/18 [==============================] - 0s 15ms/step - loss: 0.5232 - accuracy: 0.8614 - val_loss: 1.6189 - val_accuracy: 0.6756 - lr: 1.5625e-05
# Epoch 72/200
# 18/18 [==============================] - 0s 19ms/step - loss: 0.5327 - accuracy: 0.8618 - val_loss: 1.6210 - val_accuracy: 0.6807 - lr: 1.5625e-05
# Epoch 73/200
# 18/18 [==============================] - 0s 15ms/step - loss: 0.5315 - accuracy: 0.8614 - val_loss: 1.6276 - val_accuracy: 0.6819 - lr: 1.5625e-05
# Epoch 74/200
# 18/18 [==============================] - 0s 16ms/step - loss: 0.5223 - accuracy: 0.8618 - val_loss: 1.6342 - val_accuracy: 0.6807 - lr: 1.0000e-05
# Epoch 75/200
# 18/18 [==============================] - 0s 19ms/step - loss: 0.5359 - accuracy: 0.8586 - val_loss: 1.6338 - val_accuracy: 0.6768 - lr: 1.0000e-05
# Epoch 76/200
# 18/18 [==============================] - 0s 19ms/step - loss: 0.5245 - accuracy: 0.8586 - val_loss: 1.6302 - val_accuracy: 0.6832 - lr: 1.0000e-05
# Epoch 77/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.5252 - accuracy: 0.8596 - val_loss: 1.6293 - val_accuracy: 0.6756 - lr: 1.0000e-05
# Epoch 78/200
# 18/18 [==============================] - 0s 18ms/step - loss: 0.5314 - accuracy: 0.8632 - val_loss: 1.6301 - val_accuracy: 0.6794 - lr: 1.0000e-05
# Epoch 79/200
# 18/18 [==============================] - 0s 16ms/step - loss: 0.5208 - accuracy: 0.8651 - val_loss: 1.6356 - val_accuracy: 0.6768 - lr: 1.0000e-05
# Epoch 80/200
# 18/18 [==============================] - 0s 18ms/step - loss: 0.5258 - accuracy: 0.8573 - val_loss: 1.6347 - val_accuracy: 0.6768 - lr: 1.0000e-05
# Epoch 81/200
# 18/18 [==============================] - 0s 16ms/step - loss: 0.5223 - accuracy: 0.8618 - val_loss: 1.6388 - val_accuracy: 0.6768 - lr: 1.0000e-05
# Epoch 82/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.5133 - accuracy: 0.8651 - val_loss: 1.6415 - val_accuracy: 0.6794 - lr: 1.0000e-05
# Epoch 83/200
# 18/18 [==============================] - 0s 16ms/step - loss: 0.5213 - accuracy: 0.8701 - val_loss: 1.6427 - val_accuracy: 0.6768 - lr: 1.0000e-05
#
# 25/25 [==============================] - 0s 5ms/step - loss: 1.6427 - accuracy: 0.6768
# Validation scores for each model:
# Score of model  0
# [1.6427226066589355, 0.6768447756767273]

# %%
# Predict the test set with the RNN
predictions = model.predict(X_val)
predictions.shape
# Out:
# 8/8 [==============================] - 0s 22ms/step
# 8/8 [==============================] - 0s 3ms/step
# 8/8 [==============================] - 0s 3ms/step
# 8/8 [==============================] - 0s 3ms/step
# 8/8 [==============================] - 0s 3ms/step
# 8/8 [==============================] - 0s 4ms/step
# 8/8 [==============================] - 0s 3ms/step
# 8/8 [==============================] - 0s 3ms/step
# 8/8 [==============================] - 0s 3ms/step
# 8/8 [==============================] - 0s 4ms/step
# 8/8 [==============================] - 0s 3ms/step
# 8/8 [==============================] - 0s 4ms/step
# 8/8 [==============================] - 0s 4ms/step
# 8/8 [==============================] - 0s 4ms/step
# 8/8 [==============================] - 0s 4ms/step
# 8/8 [==============================] - 0s 4ms/step
# 8/8 [==============================] - 0s 4ms/step
# 8/8 [==============================] - 0s 4ms/step
# 8/8 [==============================] - 0s 4ms/step
# 8/8 [==============================] - 0s 4ms/step
# (243, 12)

# %%
# Compute the confusion matrix
cm = confusion_matrix(np.argmax(y_val, axis=-1), np.argmax(predictions, axis=-1))

# Compute the classification metrics
accuracy = accuracy_score(np.argmax(y_val, axis=-1), np.argmax(predictions, axis=-1))
precision = precision_score(np.argmax(y_val, axis=-1), np.argmax(predictions, axis=-1), average='macro')
recall = recall_score(np.argmax(y_val, axis=-1), np.argmax(predictions, axis=-1), average='macro')
f1 = f1_score(np.argmax(y_val, axis=-1), np.argmax(predictions, axis=-1), average='macro')
print('Accuracy:',accuracy.round(4))
print('Precision:',precision.round(4))
print('Recall:',recall.round(4))
print('F1:',f1.round(4))

# Plot the confusion matrix
plt.figure(figsize=(10,8))
sns.heatmap(cm.T, cmap='Blues', xticklabels=list(label_mapping), yticklabels=list(label_mapping), annot=True)
plt.xlabel('True labels')
plt.ylabel('Predicted labels')
plt.show()
# Out:
# Accuracy: 0.7819
# Precision: 0.7074
# Recall: 0.6816
# F1: 0.6277
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
f1s = f1_score(np.argmax(y_val, axis=-1), np.argmax(predictions, axis=-1), average=None)

fig = plt.figure(figsize=(21, 5))
plt.bar(np.arange(12), f1s, width=1, edgecolor="white", tick_label=list(label_mapping))

plt.show()

# %% [markdown]
# # Save the model

# %%
model.save(model_name)
#model.load(model_name)
# Out:
# WARNING:absl:Function `_wrapped_model` contains input name(s) Input with unsupported characters which will be renamed to input in the SavedModel.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 8). These functions will not be directly callable after loading.
# WARNING:absl:Function `_wrapped_model` contains input name(s) Input with unsupported characters which will be renamed to input in the SavedModel.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 8). These functions will not be directly callable after loading.
# WARNING:absl:Function `_wrapped_model` contains input name(s) Input with unsupported characters which will be renamed to input in the SavedModel.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 8). These functions will not be directly callable after loading.
# WARNING:absl:Function `_wrapped_model` contains input name(s) Input with unsupported characters which will be renamed to input in the SavedModel.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 8). These functions will not be directly callable after loading.
# WARNING:absl:Function `_wrapped_model` contains input name(s) Input with unsupported characters which will be renamed to input in the SavedModel.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 8). These functions will not be directly callable after loading.
# WARNING:absl:Function `_wrapped_model` contains input name(s) Input with unsupported characters which will be renamed to input in the SavedModel.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 8). These functions will not be directly callable after loading.
# WARNING:absl:Function `_wrapped_model` contains input name(s) Input with unsupported characters which will be renamed to input in the SavedModel.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 8). These functions will not be directly callable after loading.
# WARNING:absl:Function `_wrapped_model` contains input name(s) Input with unsupported characters which will be renamed to input in the SavedModel.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 8). These functions will not be directly callable after loading.
# WARNING:absl:Function `_wrapped_model` contains input name(s) Input with unsupported characters which will be renamed to input in the SavedModel.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 8). These functions will not be directly callable after loading.
# WARNING:absl:Function `_wrapped_model` contains input name(s) Input with unsupported characters which will be renamed to input in the SavedModel.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 8). These functions will not be directly callable after loading.
# WARNING:absl:Function `_wrapped_model` contains input name(s) Input with unsupported characters which will be renamed to input in the SavedModel.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 8). These functions will not be directly callable after loading.
# WARNING:absl:Function `_wrapped_model` contains input name(s) Input with unsupported characters which will be renamed to input in the SavedModel.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 8). These functions will not be directly callable after loading.
# WARNING:absl:Function `_wrapped_model` contains input name(s) Input with unsupported characters which will be renamed to input in the SavedModel.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 8). These functions will not be directly callable after loading.
# WARNING:absl:Function `_wrapped_model` contains input name(s) Input with unsupported characters which will be renamed to input in the SavedModel.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 8). These functions will not be directly callable after loading.
# WARNING:absl:Function `_wrapped_model` contains input name(s) Input with unsupported characters which will be renamed to input in the SavedModel.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 8). These functions will not be directly callable after loading.
# WARNING:absl:Function `_wrapped_model` contains input name(s) Input with unsupported characters which will be renamed to input in the SavedModel.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 8). These functions will not be directly callable after loading.
# WARNING:absl:Function `_wrapped_model` contains input name(s) Input with unsupported characters which will be renamed to input in the SavedModel.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 8). These functions will not be directly callable after loading.
# WARNING:absl:Function `_wrapped_model` contains input name(s) Input with unsupported characters which will be renamed to input in the SavedModel.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 8). These functions will not be directly callable after loading.
# WARNING:absl:Function `_wrapped_model` contains input name(s) Input with unsupported characters which will be renamed to input in the SavedModel.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 8). These functions will not be directly callable after loading.
# WARNING:absl:Function `_wrapped_model` contains input name(s) Input with unsupported characters which will be renamed to input in the SavedModel.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 8). These functions will not be directly callable after loading.
